# %% [markdown]
# # This is a markdown file exploring and cleaning WHO Data.  This is just to get a feel for the data and to see how they compare across resources.  We may find that the data is basically the same, which is highly possible.

# %%
import pandas as pd

# %% [markdown]
# ## Load the data

# %%
who = pd.read_csv("WHO_data/WHO 2017-2019.csv")
unicef = pd.read_csv("UNICEF_data/UNICEF-IMR-2018.csv")

# %% [markdown]
# ## Step 1: Examine and clean the WHO data

# %%
who.head()
# Out:
#               GHO PUBLISHSTATE  YEAR REGION UNREGION WORLDBANKINCOMEGROUP  \
# 0  MDG_0000000001    PUBLISHED  2018    EMR      NaN                  NaN
# 1  MDG_0000000001    PUBLISHED  2018    EMR      NaN                  NaN
# 2  MDG_0000000001    PUBLISHED  2018    EMR      NaN                  NaN
# 3  MDG_0000000001    PUBLISHED  2018    AFR      NaN                  NaN
# 4  MDG_0000000001    PUBLISHED  2018    AFR      NaN                  NaN
#
#   COUNTRY   SEX  Display Value   Numeric       Low      High Comments
# 0     AFG  BTSX           48.0  48.04333  39.94430  56.32006      NaN
# 1     AFG  FMLE           44.6  44.55944  36.87615  52.43261      NaN
# 2     AFG   MLE           51.3  51.34710  42.55961  60.39946      NaN
# 3     AGO  BTSX           51.9  51.87144  28.20570  87.37608      NaN
# 4     AGO  FMLE           46.3  46.32707  25.06762  78.38194      NaN

# %%
who_cols = [
    'GHO', 
    'YEAR', 
    'REGION',
    'COUNTRY',    
    'SEX',
    'Display Value',
    'Numeric',
    'Low',
    'High'
]

# %% [markdown]
# ### Based on the numbers in the WHO dataset vs. UNICEF, it's safe to say that BTSX is a code for the combined IMR of Male and Female, as the numbers match with UNICEF in that regard

# %%
who = who[who_cols]
sex_filter = who['SEX'] == 'BTSX'
year_filter = who['YEAR'] == 2018
who = who[sex_filter]
who = who[year_filter]
who.head()
# Out:
#                GHO  YEAR REGION COUNTRY   SEX  Display Value   Numeric  \
# 0   MDG_0000000001  2018    EMR     AFG  BTSX           48.0  48.04333
# 3   MDG_0000000001  2018    AFR     AGO  BTSX           51.9  51.87144
# 6   MDG_0000000001  2018    EUR     ALB  BTSX            8.5   8.47357
# 9   MDG_0000000001  2018    EUR     AND  BTSX            2.9   2.94139
# 12  MDG_0000000001  2018    EMR     ARE  BTSX            6.5   6.50609
#
#          Low      High
# 0   39.94430  56.32006
# 3   28.20570  87.37608
# 6    8.06406   8.91675
# 9    0.86802  10.54429
# 12   5.75564   7.35071

# %% [markdown]
# ## Step 2: Examine UNICEF Data

# %%
unicef.head()
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...             ALB: Albania
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...             ALB: Albania
#
#                INDICATOR:Indicator    SEX:Sex  TIME_PERIOD:Time period  \
# 0  CME_MRY0: Infant mortality rate  F: Female                     2018
# 1  CME_MRY0: Infant mortality rate    M: Male                     2018
# 2  CME_MRY0: Infant mortality rate  _T: Total                     2018
# 3  CME_MRY0: Infant mortality rate  F: Female                     2018
# 4  CME_MRY0: Infant mortality rate    M: Male                     2018
#
#    OBS_VALUE:Observation Value  UNIT_MULTIPLIER:Unit multiplier  \
# 0                    44.559440                              NaN
# 1                    51.347098                              NaN
# 2                    48.043335                              NaN
# 3                     7.551900                              NaN
# 4                     9.340910                              NaN
#
#                 UNIT_MEASURE:Unit of measure OBS_STATUS:Observation Status  \
# 0  D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 1  D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 2  D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 3  D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 4  D_PER_1000_B: Deaths per 1000 live births               A: Normal value
#
#    OBS_CONF:Observation confidentaility  ...  \
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
#
#    WGTD_SAMPL_SIZE:Weighted Sample Size  OBS_FOOTNOTE:Observation footnote  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
#
#    SERIES_FOOTNOTE:Series footnote DATA_SOURCE:Data Source  \
# 0                              NaN                     NaN
# 1                              NaN                     NaN
# 2                              NaN                     NaN
# 3                              NaN                     NaN
# 4                              NaN                     NaN
#
#    SOURCE_LINK:Citation of or link to the data source  CUSTODIAN:Custodian  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#    TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    REF_PERIOD:Reference Period  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#    COVERAGE_TIME:The period of time for which data are provided  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AGE:Current age
# 0        _T: Total
# 1        _T: Total
# 2        _T: Total
# 3        _T: Total
# 4        _T: Total
#
# [5 rows x 22 columns]

# %% [markdown]
# ## The data and column names in UNICEF are much more specific, which is good and bad.  We're going to reformat some of it to make it easier to join data, and we will only look at columns we find relevant for the analysis to make it easier to work with

# %%
unicef[['REF_AREA','Geographic area']] = unicef['REF_AREA:Geographic area'].str.split(":",expand=True)

# %%
unicef_cols = ['DATAFLOW', 'REF_AREA', 'Geographic area', 'INDICATOR:Indicator',
       'SEX:Sex', 'TIME_PERIOD:Time period', 'OBS_VALUE:Observation Value',
       'UNIT_MEASURE:Unit of measure',
       'OBS_STATUS:Observation Status',
       'LOWER_BOUND:Lower Bound', 'UPPER_BOUND:Upper Bound']

# %%
unicef = unicef[unicef_cols].copy()

# %%
unicef_filter = unicef["SEX:Sex"] == "_T: Total"
unicef = unicef[unicef_filter]
unicef.head()
# Out:
#                                              DATAFLOW REF_AREA  \
# 2   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...      AFG
# 5   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...      ALB
# 8   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...      DZA
# 11  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...      AND
# 14  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...      AGO
#
#    Geographic area              INDICATOR:Indicator    SEX:Sex  \
# 2      Afghanistan  CME_MRY0: Infant mortality rate  _T: Total
# 5          Albania  CME_MRY0: Infant mortality rate  _T: Total
# 8          Algeria  CME_MRY0: Infant mortality rate  _T: Total
# 11         Andorra  CME_MRY0: Infant mortality rate  _T: Total
# 14          Angola  CME_MRY0: Infant mortality rate  _T: Total
#
#     TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 2                      2018                    48.043335
# 5                      2018                     8.473569
# 8                      2018                    20.429315
# 11                     2018                     2.941386
# 14                     2018                    51.871440
#
#                  UNIT_MEASURE:Unit of measure OBS_STATUS:Observation Status  \
# 2   D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 5   D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 8   D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 11  D_PER_1000_B: Deaths per 1000 live births               A: Normal value
# 14  D_PER_1000_B: Deaths per 1000 live births               A: Normal value
#
#     LOWER_BOUND:Lower Bound  UPPER_BOUND:Upper Bound
# 2                 39.944302                56.320057
# 5                  8.064059                 8.916751
# 8                 19.960411                20.895252
# 11                 0.868024                10.544288
# 14                28.205699                87.376078

# %%
unicef
# Out:
#                                               DATAFLOW  \
# 2    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 5    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 8    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 11   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 14   UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# ..                                                 ...
# 680  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 683  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 686  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 691  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 692  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
#
#                    REF_AREA      Geographic area  \
# 2                       AFG          Afghanistan
# 5                       ALB              Albania
# 8                       DZA              Algeria
# 11                      AND              Andorra
# 14                      AGO               Angola
# ..                      ...                  ...
# 680                     YEM                Yemen
# 683                     ZMB               Zambia
# 686                     ZWE             Zimbabwe
# 691              UNICEF_SSA   sub-Saharan Africa
# 692  UNSDG_SUBSAHARANAFRICA   sub-Saharan Africa
#
#                  INDICATOR:Indicator    SEX:Sex  TIME_PERIOD:Time period  \
# 2    CME_MRY0: Infant mortality rate  _T: Total                     2018
# 5    CME_MRY0: Infant mortality rate  _T: Total                     2018
# 8    CME_MRY0: Infant mortality rate  _T: Total                     2018
# 11   CME_MRY0: Infant mortality rate  _T: Total                     2018
# 14   CME_MRY0: Infant mortality rate  _T: Total                     2018
# ..                               ...        ...                      ...
# 680  CME_MRY0: Infant mortality rate  _T: Total                     2018
# 683  CME_MRY0: Infant mortality rate  _T: Total                     2018
# 686  CME_MRY0: Infant mortality rate  _T: Total                     2018
# 691  CME_MRY0: Infant mortality rate  _T: Total                     2018
# 692  CME_MRY0: Infant mortality rate  _T: Total                     2018
#
#      OBS_VALUE:Observation Value               UNIT_MEASURE:Unit of measure  \
# 2                      48.043335  D_PER_1000_B: Deaths per 1000 live births
# 5                       8.473569  D_PER_1000_B: Deaths per 1000 live births
# 8                      20.429315  D_PER_1000_B: Deaths per 1000 live births
# 11                      2.941386  D_PER_1000_B: Deaths per 1000 live births
# 14                     51.871440  D_PER_1000_B: Deaths per 1000 live births
# ..                           ...                                        ...
# 680                    43.639697  D_PER_1000_B: Deaths per 1000 live births
# 683                    43.364637  D_PER_1000_B: Deaths per 1000 live births
# 686                    39.273756  D_PER_1000_B: Deaths per 1000 live births
# 691                    53.021824  D_PER_1000_B: Deaths per 1000 live births
# 692                    53.425611  D_PER_1000_B: Deaths per 1000 live births
#
#     OBS_STATUS:Observation Status  LOWER_BOUND:Lower Bound  \
# 2                 A: Normal value                39.944302
# 5                 A: Normal value                 8.064059
# 8                 A: Normal value                19.960411
# 11                A: Normal value                 0.868024
# 14                A: Normal value                28.205699
# ..                            ...                      ...
# 680               A: Normal value                29.245932
# 683               A: Normal value                36.935594
# 686               A: Normal value                32.471826
# 691               A: Normal value                49.846879
# 692               A: Normal value                50.165521
#
#      UPPER_BOUND:Upper Bound
# 2                  56.320057
# 5                   8.916751
# 8                  20.895252
# 11                 10.544288
# 14                 87.376078
# ..                       ...
# 680                63.183587
# 683                50.962951
# 686                47.225792
# 691                57.927077
# 692                58.511552
#
# [231 rows x 11 columns]
