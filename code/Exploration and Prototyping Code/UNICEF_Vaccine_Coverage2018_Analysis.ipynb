# %%
import pandas as pd
import data_cleaner as clean

# %%
vaccine_coverage2018 = pd.read_csv("../data/UNICEF-VACCINE-COVERAGE-BY-ANTIGEN-2018.csv")
imr2018 = pd.read_csv("../data/UNICEF-IMR-2018.csv")

# %%
vaccine_coverage2018.dropna(how="all", axis=1, inplace=True)
clean.split_cols(vaccine_coverage2018, "REF_AREA:Geographic area")

imr2018.dropna(how="all", axis=1, inplace=True)
clean.split_cols(imr2018, "REF_AREA:Geographic area")
# Out:
#                                               DATAFLOW  \
# 0    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 1    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 2    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 3    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 4    UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# ..                                                 ...
# 688  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 689  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 690  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 691  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# 692  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
#
#                  INDICATOR:Indicator    SEX:Sex  TIME_PERIOD:Time period  \
# 0    CME_MRY0: Infant mortality rate  F: Female                     2018
# 1    CME_MRY0: Infant mortality rate    M: Male                     2018
# 2    CME_MRY0: Infant mortality rate  _T: Total                     2018
# ...

# %%
imr2018.describe()
# Out:
#        TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# count                    693.0                   693.000000
# mean                    2018.0                    21.710649
# std                        0.0                    19.210807
# min                     2018.0                     1.414661
# 25%                     2018.0                     6.130073
# 50%                     2018.0                    15.059466
# 75%                     2018.0                    32.959162
# max                     2018.0                    90.088460
#
#        LOWER_BOUND:Lower Bound  UPPER_BOUND:Upper Bound
# count               693.000000               693.000000
# mean                 17.110511                28.182027
# std                  15.193243                26.270889
# min                   0.753374                 1.820345
# 25%                   5.323662                 7.106328
# 50%                  11.651276                19.461561
# ...

# %%
imr2018['OBS_FOOTNOTE:Observation footnote'].value_counts()
# Out:
# The mortality rates used as underlying data and shown as “VR submitted to WHO/UNIGME 2020 version (VR)” are calculated by UN IGME using standard methods with data from Rosstat.                                                                                                                3
# The most recent national official estimates of neonatal, infant and under-five mortality rates in India are from the India Sample Registration System with a rate of 23, 32 and 36 deaths per 1,000 live births, respectively, in the year 2018.                                                3
# The most recent national official estimates of neonatal, infant and under-five mortality rates in Zambia are from the 2018 Zambia Demographic and Health Survey (2018 ZDHS) with a rate of 27, 42 and 61 deaths per 1,000 live births, respectively, in the 5-year period before the survey.    3
# Name: OBS_FOOTNOTE:Observation footnote, dtype: int64

# %%
vaccine_coverage2018.describe()
# Out:
#        TIME_PERIOD:Time period  OBS_VALUE:Observation Value
# count                   2410.0                  2410.000000
# mean                    2018.0                    84.536515
# std                        0.0                    17.850578
# min                     2018.0                     1.000000
# 25%                     2018.0                    80.000000
# 50%                     2018.0                    91.000000
# 75%                     2018.0                    97.000000
# max                     2018.0                    99.000000
