# %%
import pandas as pd
import data_cleaner as clean

# %%
who_1 = pd.read_csv("../data/WHO-CHILD-HEALTH-1.csv")
who_2 = pd.read_csv("../data/WHO-CHILD-HEALTH-2a.csv")
who_3 = pd.read_csv("../data/WHO-CHILD-HEALTH-3.csv")
who_4 = pd.read_csv("../data/WHO-CHILD-HEALTH-4.csv")
imr = pd.read_csv("../data/WHO-IMR-2017-2019.csv")

# %%
who_1.head()
# Out:
#         GHO PUBLISHSTATE  YEAR REGION WORLDBANKINCOMEGROUP COUNTRY  \
# 0      PCV3    PUBLISHED  2015    EMR                WB_LI     AFG
# 1  WHS4_100    PUBLISHED  1992    EMR                WB_LI     AFG
# 2  WHS4_100    PUBLISHED  1995    EMR                WB_LI     AFG
# 3  WHS4_100    PUBLISHED  2012    EMR                WB_LI     AFG
# 4  WHS4_543    PUBLISHED  1982    EMR                WB_LI     AFG
#
#    Display Value  Numeric  Low  High  Comments
# 0             65     65.0  NaN   NaN       NaN
# 1             21     21.0  NaN   NaN       NaN
# 2             20     20.0  NaN   NaN       NaN
# 3             67     67.0  NaN   NaN       NaN
# 4             10     10.0  NaN   NaN       NaN

# %%
# Filter and restructure the dataset to make it easier to work with

year_filter = who_1['YEAR'] == 2018
who_1 = who_1[year_filter]

who_subset = who_1[['GHO', 'YEAR', 'COUNTRY', 'Numeric']]

countries = sorted(list(set(who_subset['COUNTRY'])))
codes = sorted(list(set(who_subset['GHO'])))
index = pd.Index(countries, name='COUNTRY')

new_df = pd.DataFrame(index=index, columns=codes)

# %%
new_df.head()
# Out:
#         PCV3 ROTAC WHS4_100 WHS4_117 WHS4_129 WHS4_543 WHS4_544 WHS8_110
# COUNTRY
# AFG      NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN
# AGO      NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ALB      NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN
# AND      NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ARE      NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %%
code = codes[0]
print("Code:", code)
filter = who_subset['GHO'] == code
who_subset[filter].head()
# Out:
# Code: PCV3
#       GHO  YEAR COUNTRY  Numeric
# 100  PCV3  2018     BGD     97.0
# 368  PCV3  2018     ESP     93.0
# 474  PCV3  2018     BDI     90.0
# 592  PCV3  2018     CHE     84.0
# 598  PCV3  2018     CHL     93.0

# %%
country = countries[0]
print("Country:", country)
filter = who_subset['COUNTRY'] == country
test = who_subset[filter].head()
test.index = test['GHO']
test[['GHO', 'Numeric']].T
# Out:
# Country: AFG
# GHO      WHS8_110  PCV3  WHS4_100  WHS4_544  WHS4_129
# GHO      WHS8_110  PCV3  WHS4_100  WHS4_544  WHS4_129
# Numeric        64    65        66        73        66

# %%
who_2['SEX'].value_counts()
# Out:
# FMLE    1690
# MLE     1690
# Name: SEX, dtype: int64

# %%
who_3.head()
# Out:
#        GHO DATASOURCE PUBLISHSTATE  YEAR REGION WORLDBANKINCOMEGROUP COUNTRY  \
# 0  pncall5     EQ_DHS    PUBLISHED  2008    EUR                  NaN     ALB
# 1  pncall3     EQ_DHS    PUBLISHED  2010    EUR                  NaN     ARM
# 2  pncall5     EQ_DHS    PUBLISHED  2010    EUR                  NaN     ARM
# 3  pncall3     EQ_DHS    PUBLISHED  2007   SEAR                  NaN     BGD
# 4  pncall5     EQ_DHS    PUBLISHED  2007   SEAR                  NaN     BGD
#
#   EDUCATIONLEVEL   SEX RESIDENCEAREATYPE WEALTHQUINTILE Display Value  \
# 0            NaN   MLE               NaN            NaN          98.5
# 1            NaN  FMLE               NaN            NaN         100.0
# 2            NaN  FMLE               NaN            NaN          99.8
# 3            NaN  FMLE               NaN            NaN          23.1
# 4            NaN  FMLE               NaN            NaN          21.0
#
#    Numeric  Low  High Comments
# 0    98.46  NaN   NaN      NaN
# 1   100.00  NaN   NaN      NaN
# 2    99.79  NaN   NaN      NaN
# 3    23.10  NaN   NaN      NaN
# 4    21.05  NaN   NaN      NaN

# %%
who_3['SEX'].value_counts()
# Out:
# BTSX    809
# MLE     642
# FMLE    639
# Name: SEX, dtype: int64

# %%
who_4.head()
# Out:
#              GHO PUBLISHSTATE  YEAR REGION WORLDBANKINCOMEGROUP COUNTRY  SEX  \
# 0  WHOSIS_000005    PUBLISHED  2008    AMR               WB_LMI     BLZ  NaN
# 1  WHOSIS_000005    PUBLISHED  2006    AFR                WB_LI     BEN  NaN
# 2  WHOSIS_000005    PUBLISHED  2008   SEAR               WB_LMI     BTN  NaN
# 3  WHOSIS_000005    PUBLISHED  2008    AMR               WB_LMI     BOL  NaN
# 4  WHOSIS_000005    PUBLISHED  2008    WPR               WB_LMI     CHN  NaN
#
#   Display Value  Numeric  Low  High Comments
# 0            14      NaN  NaN   NaN      NaN
# 1            15      NaN  NaN   NaN      NaN
# 2             9      NaN  NaN   NaN      NaN
# 3             6      NaN  NaN   NaN      NaN
# 4             3      NaN  NaN   NaN      NaN

# %%
who_4['SEX'].value_counts()
# Out:
# BTSX    3696
# Name: SEX, dtype: int64

# %%
for col in who_4.columns:
    print(col)
    print(who_4[col].value_counts())
    print()
# Out:
# GHO
# LBW_NUMBER        2336
# LBW_PREVALENCE    2336
# NUTRITION_WH2      924
# NUTRITION_WA_2     924
# NUTRITION_WH_2     924
# NUTRITION_HA_2     924
# WHOSIS_000006      530
# WHOSIS_000005      215
# Name: GHO, dtype: int64
#
# PUBLISHSTATE
# PUBLISHED    9113
# Name: PUBLISHSTATE, dtype: int64
#
# YEAR
# 2000         569
# 2006         526
# 2014         463
# 2012         445
# 2005         440
#             ...
# 2014-2017      4
# 2009-2011      4
# 1986-1988      4
# 1985-1986      4
# 2007-2010      4
# Name: YEAR, Length: 85, dtype: int64
#
# REGION
# AFR     2628
# EUR     2124
# AMR     1852
# WPR      972
# EMR      791
# SEAR     722
# Name: REGION, dtype: int64
#
# WORLDBANKINCOMEGROUP
# WB_LMI    50
# WB_UMI    40
# WB_LI     40
# WB_HI     29
# Name: WORLDBANKINCOMEGROUP, dtype: int64
#
# COUNTRY
# BGD    137
# VNM    128
# VEN    118
# JAM    115
# PER    107
#       ...
# GRD      1
# CYP      1
# NIU      1
# PLW      1
# FSM      1
# Name: COUNTRY, Length: 195, dtype: int64
#
# SEX
# BTSX    3696
# Name: SEX, dtype: int64
#
# Display Value
# 0.0 [0.0-0.0]       48
# 1.6                 34
# 2.4                 31
# 2.5                 31
# 4.0                 31
#                     ..
# 14.2 [11.1-19.1]     1
# 11.4 [8.8-14.9]      1
# 12.2 [9.7-15.5]      1
# 37.8 [37.3-38.2]     1
# 20.5 [15.9-27.4]     1
# Name: Display Value, Length: 4011, dtype: int64
#
# Numeric
# 0.70000     69
# 0.00000     69
# 5.00000     61
# 5.30000     59
# 4.60000     56
#             ..
# 11.32335     1
# 23.85968     1
# 1.51331      1
# 11.09331     1
# 14.59289     1
# Name: Numeric, Length: 3252, dtype: int64
#
# Low
# 5.9      65
# 0.0      64
# 6.0      57
# 8.2      52
# 8.3      49
#          ..
# 135.2     1
# 76.6      1
# 33.3      1
# 53.1      1
# 60.4      1
# Name: Low, Length: 843, dtype: int64
#
# High
# 7.0       50
# 0.2       48
# 0.0       48
# 6.3       40
# 5.1       39
#           ..
# 75.0       1
# 32.5       1
# 268.5      1
# 192.6      1
# 1117.7     1
# Name: High, Length: 1001, dtype: int64
#
# Comments
# NNS. Annual national nutrition monitoring. Nutrition Surveillance Department. Hanoi, Vietnam: National Institute of Nutrition, 2009 (and additional analysis)..Tuyen le D..                                                                                                                                                                                                                                    32
# Surveillance. Ficha técnica: Evaluación antropométrica nutricional en menores de 5 años según criterios internacionales. Caracas, Venezuela: Gobierno Bolivariano de Venezuela, Ministerio del Poder Popular para la Salud, INN, 2012 (and additional analysis)..Gobierno Bolivariano de Venezuela, Ministerio del Poder Popular para la Salud, Instituto Nacional de Nutrición (INN).. Converted estimates    32
# Data refer to exclusive breastfeeding at 6 months.  These estimates are lower than the standard measure of exclusive breastfeeding averaged over the first six months.                                                                                                                                                                                                                                         21
# Surveillance. Kuwait nutrition surveillance system, 2005 report: 2001-2005 trends. Kuwait, State of Kuwait: Administration of Food and Nutrition, Ministry of Health, 2006 (and additional analysis)..Administration of Food and Nutrition, Ministry of Health.. National Surveillance System                                                                                                                  20
# Surveillance. Kuwait nutrition surveillance system: 2006-2009 trends. Kuwait, State of Kuwait: Administration of Food and Nutrition, Ministry of Health, 2010 (and additional analysis)..Administration of Food and Nutrition, Ministry of Health.. National Surveillance System                                                                                                                               16
#                                                                                                                                                                                                                                                                                                                                                                                                                ..
# Data for years 1997-1998                                                                                                                                                                                                                                                                                                                                                                                        1
# non-standard definition, pending reanalysis                                                                                                                                                                                                                                                                                                                                                                     1
# Exclusive and predominant breastfeeding estimates for Kenya DHS 2014 changed from reanalyzed to reported following the release of new dataset. Reanalyzed estimates will be updated on completion of analysis.                                                                                                                                                                                                  1
# Retracted, under review                                                                                                                                                                                                                                                                                                                                                                                         1
# Data for years 2004-2005                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: Comments, Length: 891, dtype: int64

# %%
imr.head()
# Out:
#               GHO PUBLISHSTATE  YEAR REGION UNREGION WORLDBANKINCOMEGROUP  \
# 0  MDG_0000000001    PUBLISHED  2018    EMR      NaN                  NaN
# 1  MDG_0000000001    PUBLISHED  2018    EMR      NaN                  NaN
# 2  MDG_0000000001    PUBLISHED  2018    EMR      NaN                  NaN
# 3  MDG_0000000001    PUBLISHED  2018    AFR      NaN                  NaN
# 4  MDG_0000000001    PUBLISHED  2018    AFR      NaN                  NaN
#
#   COUNTRY   SEX  Display Value   Numeric       Low      High Comments
# 0     AFG  BTSX           48.0  48.04333  39.94430  56.32006      NaN
# 1     AFG  FMLE           44.6  44.55944  36.87615  52.43261      NaN
# 2     AFG   MLE           51.3  51.34710  42.55961  60.39946      NaN
# 3     AGO  BTSX           51.9  51.87144  28.20570  87.37608      NaN
# 4     AGO  FMLE           46.3  46.32707  25.06762  78.38194      NaN

# %%
who_1['Country_Year'] = who_1['COUNTRY'].str.cat(who_1['YEAR'].astype(str),sep="_")

# %%
who_1.head()
# Out:
#                    GHO PUBLISHSTATE  YEAR REGION WORLDBANKINCOMEGROUP COUNTRY  \
# Country_Year
# ALB_2018      WHS4_544    PUBLISHED  2018    EUR               WB_UMI     ALB
# AUS_2018         ROTAC    PUBLISHED  2018    WPR                WB_HI     AUS
# AUS_2018      WHS4_129    PUBLISHED  2018    WPR                WB_HI     AUS
# AUT_2018      WHS4_129    PUBLISHED  2018    EUR                WB_HI     AUT
# BFA_2018      WHS4_543    PUBLISHED  2018    AFR                WB_LI     BFA
#
#               Display Value  Numeric  Low  High  Comments
# Country_Year
# ALB_2018                 99     99.0  NaN   NaN       NaN
# AUS_2018                 87     87.0  NaN   NaN       NaN
# AUS_2018                 94     94.0  NaN   NaN       NaN
# AUT_2018                 85     85.0  NaN   NaN       NaN
# BFA_2018                 98     98.0  NaN   NaN       NaN

# %%
who_1 = who_1.set_index('Country_Year')

# %%
who_subset[who_subset['COUNTRY'] == 'AUS']
# Out:
#                    GHO  Display Value COUNTRY  YEAR
# Country_Year
# AUS_2018         ROTAC             87     AUS  2018
# AUS_2018      WHS4_129             94     AUS  2018
# AUS_2018      WHS4_117             95     AUS  2018
# AUS_2018      WHS4_100             95     AUS  2018
# AUS_2018      WHS4_544             95     AUS  2018
# AUS_2018      WHS8_110             95     AUS  2018
# AUS_2018          PCV3             95     AUS  2018

# %%
who_subset[who_subset['GHO'] == 'ROTAC']
# Out:
#                 GHO  Display Value COUNTRY  YEAR
# Country_Year
# AUS_2018      ROTAC             87     AUS  2018
# BRA_2018      ROTAC             80     BRA  2018
# BHR_2018      ROTAC             98     BHR  2018
# ERI_2018      ROTAC             96     ERI  2018
# FSM_2018      ROTAC             52     FSM  2018
# ...             ...            ...     ...   ...
# KEN_2018      ROTAC             92     KEN  2018
# KWT_2018      ROTAC             69     KWT  2018
# LVA_2018      ROTAC             79     LVA  2018
# SLE_2018      ROTAC             92     SLE  2018
# SWZ_2018      ROTAC             90     SWZ  2018
#
# [97 rows x 4 columns]

# %%
test_df = pd.DataFrame(index = who_subset.index)

# %%
who_subset.head()
# Out:
#                    GHO  Display Value COUNTRY  YEAR
# Country_Year
# ALB_2018      WHS4_544             99     ALB  2018
# AUS_2018         ROTAC             87     AUS  2018
# AUS_2018      WHS4_129             94     AUS  2018
# AUT_2018      WHS4_129             85     AUT  2018
# BFA_2018      WHS4_543             98     BFA  2018

# %%
who_subset_usa = who_subset[who_subset['COUNTRY'] == 'USA']

# %%
who_subset_usa.T.head()
# Out:
# Country_Year   USA_2018  USA_2018  USA_2018 USA_2018  USA_2018  USA_2018  \
# GHO            WHS8_110  WHS4_544  WHS4_117    ROTAC  WHS4_129  WHS4_100
# Display Value        92        93        91       73        92        94
# COUNTRY             USA       USA       USA      USA       USA       USA
#
# Country_Year  USA_2018
# GHO               PCV3
# Display Value       92
# COUNTRY            USA

# %%
who_1.head()
# Out:
#                    GHO PUBLISHSTATE  YEAR REGION WORLDBANKINCOMEGROUP COUNTRY  \
# Country_Year
# ALB_2018      WHS4_544    PUBLISHED  2018    EUR               WB_UMI     ALB
# AUS_2018         ROTAC    PUBLISHED  2018    WPR                WB_HI     AUS
# AUS_2018      WHS4_129    PUBLISHED  2018    WPR                WB_HI     AUS
# AUT_2018      WHS4_129    PUBLISHED  2018    EUR                WB_HI     AUT
# BFA_2018      WHS4_543    PUBLISHED  2018    AFR                WB_LI     BFA
#
#               Display Value  Numeric  Low  High  Comments
# Country_Year
# ALB_2018                 99     99.0  NaN   NaN       NaN
# AUS_2018                 87     87.0  NaN   NaN       NaN
# AUS_2018                 94     94.0  NaN   NaN       NaN
# AUT_2018                 85     85.0  NaN   NaN       NaN
# BFA_2018                 98     98.0  NaN   NaN       NaN

# %%
who1b
# Out:
#         PCV3 ROTAC WHS4_100 WHS4_117 WHS4_129 WHS4_543 WHS4_544 WHS8_110
# COUNTRY
# AFG       65    45       66       66       66       78       73       64
# AGO       59    48       63       59       59       72       56       50
# ALB       98   NaN       99       99       99       99       99       94
# AND       94   NaN       99       98       99      NaN       99       99
# ARE       99    99       99       99       99       95       99       99
# ...      ...   ...      ...      ...      ...      ...      ...      ...
# WSM      NaN   NaN       34       34       34       62       31       31
# YEM       64    64       65       65       65       64       59       64
# ZAF       73    70       74       74       74       70       74       70
# ZMB       90    91       90       90       90       91       90       94
# ZWE       89    90       89       89       89       95       89       88
#
# [194 rows x 8 columns]

# %%
#cleanWHO.py
import pandas as pd


who1 = pd.read_csv("../data/WHO-CHILD-HEALTH-1.csv")
pd.set_option('display.max_columns', None)


filter = who1["YEAR"] == 2018
who1 = who1[filter]
who_subset = who1[['GHO','YEAR','COUNTRY', 'Numeric']]
countries = sorted(list(set(who_subset['COUNTRY'])))
codes = sorted(list(set(who_subset['GHO'])))
index = pd.Index(countries, name='COUNTRY')

who1b = pd.DataFrame(index=index, columns=codes)

for i in countries:
    for j in codes:
        country = i
        code = j
        filter = who_subset['COUNTRY'] == country
        temp = who_subset[filter]
        factors = temp['GHO'].tolist()
        temp.index = factors
        if j not in factors:
            continue
        else:
            who1b.at[country,code] = temp.at[code, 'Numeric']

print(who1b)
# Out:
#         PCV3 ROTAC WHS4_100 WHS4_117 WHS4_129 WHS4_543 WHS4_544 WHS8_110
# COUNTRY
# AFG       65    45       66       66       66       78       73       64
# AGO       59    48       63       59       59       72       56       50
# ALB       98   NaN       99       99       99       99       99       94
# AND       94   NaN       99       98       99      NaN       99       99
# ARE       99    99       99       99       99       95       99       99
# ...      ...   ...      ...      ...      ...      ...      ...      ...
# WSM      NaN   NaN       34       34       34       62       31       31
# YEM       64    64       65       65       65       64       59       64
# ZAF       73    70       74       74       74       70       74       70
# ZMB       90    91       90       90       90       91       90       94
# ZWE       89    90       89       89       89       95       89       88
#
# [194 rows x 8 columns]

# %%
who1b
# Out:
#         PCV3 ROTAC WHS4_100 WHS4_117 WHS4_129 WHS4_543 WHS4_544 WHS8_110
# COUNTRY
# AFG       65    45       66       66       66       78       73       64
# AGO       59    48       63       59       59       72       56       50
# ALB       98   NaN       99       99       99       99       99       94
# AND       94   NaN       99       98       99      NaN       99       99
# ARE       99    99       99       99       99       95       99       99
# ...      ...   ...      ...      ...      ...      ...      ...      ...
# WSM      NaN   NaN       34       34       34       62       31       31
# YEM       64    64       65       65       65       64       59       64
# ZAF       73    70       74       74       74       70       74       70
# ZMB       90    91       90       90       90       91       90       94
# ZWE       89    90       89       89       89       95       89       88
#
# [194 rows x 8 columns]

# %%
##START HERE:

# %%
who_1 = pd.read_csv("../data/WHO-CHILD-HEALTH-1.csv")

# %%
who_1['Country_Year'] = who_1['COUNTRY'].str.cat(who_1['YEAR'].astype(str),sep="_")
who_1 = who_1.set_index('Country_Year')
test_df = pd.DataFrame(index = who_1.index)

test_df['COUNTRY'] = who_1['COUNTRY']
test_df['YEAR'] = who_1['YEAR']

for code in who_1['GHO'].unique():
    test_df[code] = who_1[who_1['GHO'] == code]['Display Value']

# %%
test_df
# Out:
#               PCV3  WHS4_100  WHS4_543  WHS4_544  WHS8_110  WHS4_117  \
# Country_Year
# AFG_2015      65.0      65.0      76.0      69.0      63.0      65.0
# AFG_1992       NaN      21.0      19.0      21.0      22.0       NaN
# AFG_1995       NaN      20.0      31.0      20.0      41.0       NaN
# AFG_2012       NaN      67.0      78.0      67.0      59.0      67.0
# AFG_1982       NaN       5.0      10.0       5.0       8.0       NaN
# ...            ...       ...       ...       ...       ...       ...
# ZWE_1995       NaN      88.0      96.0      88.0      87.0       1.0
# ZWE_2009       NaN      73.0      90.0      69.0      76.0      73.0
# ZWE_1990       NaN      88.0      91.0      89.0      87.0       NaN
# ZWE_2004       NaN      65.0      76.0      67.0      66.0      68.0
# ZWE_2013      95.0      95.0      95.0      95.0      93.0      95.0
#
#               WHS4_129  ROTAC
# Country_Year
# AFG_2015          65.0    NaN
# AFG_1992           NaN    NaN
# AFG_1995           NaN    NaN
# AFG_2012          67.0    NaN
# AFG_1982           NaN    NaN
# ...                ...    ...
# ZWE_1995           NaN    NaN
# ZWE_2009          73.0    NaN
# ZWE_1990           NaN    NaN
# ZWE_2004           NaN    NaN
# ZWE_2013          95.0    NaN
#
# [35727 rows x 8 columns]

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# load dataset into Pandas DataFrame
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width       target
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from sklearn.preprocessing import StandardScaler
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
# Separating out the features
x = df.loc[:, features].values
# Separating out the target
y = df.loc[:,['target']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)

# %%
finalDf.head()
# Out:
#    principal component 1  principal component 2       target
# 0              -2.264542               0.505704  Iris-setosa
# 1              -2.086426              -0.655405  Iris-setosa
# 2              -2.367950              -0.318477  Iris-setosa
# 3              -2.304197              -0.575368  Iris-setosa
# 4              -2.388777               0.674767  Iris-setosa

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.72770452, 0.23030523])

# %%
pca.explained_variance_
# Out:
# array([2.93035378, 0.92740362])

# %%
who_simple = pd.read_csv("../data/WHO-SIMPLE.csv")

# %%
who_simple.head()
# Out:
#   Country_Year  MDG_0000000001  PCV3  ROTAC  WHS4_100  WHS4_117  WHS4_129  \
# 0     AFG_1962       232.04606   NaN    NaN       NaN       NaN       NaN
# 1     AFG_1963       227.83111   NaN    NaN       NaN       NaN       NaN
# 2     AFG_1964       223.85301   NaN    NaN       NaN       NaN       NaN
# 3     AFG_1965       219.92361   NaN    NaN       NaN       NaN       NaN
# 4     AFG_1966       216.06007   NaN    NaN       NaN       NaN       NaN
#
#    WHS4_543  WHS4_544  WHS8_110  ...  WSH_3  WSH_SANITATION_SAFELY_MANAGED  \
# 0       NaN       NaN       NaN  ...    NaN                            NaN
# 1       NaN       NaN       NaN  ...    NaN                            NaN
# 2       NaN       NaN       NaN  ...    NaN                            NaN
# 3       NaN       NaN       NaN  ...    NaN                            NaN
# 4       NaN       NaN       NaN  ...    NaN                            NaN
#
#    M_Est_smk_curr  M_Est_smk_daily  TOBACCO_0000000192  GHED_CHEGDP_SHA2011  \
# 0             NaN              NaN                 NaN                  NaN
# 1             NaN              NaN                 NaN                  NaN
# 2             NaN              NaN                 NaN                  NaN
# 3             NaN              NaN                 NaN                  NaN
# 4             NaN              NaN                 NaN                  NaN
#
#    WHS9_85  Country Code    Year           GDP
# 0      NaN           AFG  1962.0  5.466667e+08
# 1      NaN           AFG  1963.0  7.511112e+08
# 2      NaN           AFG  1964.0  8.000000e+08
# 3      NaN           AFG  1965.0  1.006667e+09
# 4      NaN           AFG  1966.0  1.400000e+09
#
# [5 rows x 35 columns]

# %%
who_simple.columns
# Out:
# Index(['Country_Year', 'MDG_0000000001', 'PCV3', 'ROTAC', 'WHS4_100',
#        'WHS4_117', 'WHS4_129', 'WHS4_543', 'WHS4_544', 'WHS8_110', 'MCV2',
#        'NUTRITION_564', 'WHS4_128', 'LBW_NUMBER', 'LBW_PREVALENCE',
#        'NUTRITION_HA_2', 'NUTRITION_WA_2', 'NUTRITION_WH2', 'NUTRITION_WH_2',
#        'WHOSIS_000005', 'WHOSIS_000006', 'MDG_0000000026', 'WHS9_95',
#        'WHS_PBR', 'WSH_2', 'WSH_3', 'WSH_SANITATION_SAFELY_MANAGED',
#        'M_Est_smk_curr', 'M_Est_smk_daily', 'TOBACCO_0000000192',
#        'GHED_CHEGDP_SHA2011', 'WHS9_85', 'Country Code', 'Year', 'GDP'],
#       dtype='object')

# %%
usa_filter = who_simple['Country Code'] == "USA"

# %%
who_usa = who_simple[usa_filter]

# %%
# who_usa = who_usa[who_usa["Year"] >= 2000]

# %%
who_usa = who_usa.dropna(how="all")

# %%
cols_to_use = []

for col in who_usa.columns:
    if col == "Country_Year": 
        print("skipping col:", col, '\n')
    elif col == "Country Code": 
        print("skipping col:", col, '\n')
    elif col == "Year": 
        print("skipping col:", col, '\n')
    else:
        print(col)
        print(who_usa[col].value_counts())
        print()
        if len(who_usa[col].value_counts() > 10):
            cols_to_use.append(col)
# Out:
# skipping col: Country_Year
#
# MDG_0000000001
# 7.92969     1
# 12.10270    1
# 8.48050     1
# 15.93040    1
# 19.08584    1
# 8.78733     1
# 15.17808    1
# 7.35440     1
# 6.74598     1
# 6.47105     1
# 22.66503    1
# 25.88741    1
# 7.11413     1
# 5.76500     1
# 25.39648    1
# 13.17504    1
# 18.29825    1
# 10.92870    1
# 5.55743     1
# 7.02394     1
# 6.57525     1
# 6.03823     1
# 5.95398     1
# 24.89482    1
# 8.19128     1
# 23.82979    1
# 10.64615    1
# 17.50237    1
# 13.79409    1
# 10.16498    1
# 9.09776     1
# 23.26247    1
# 5.71130     1
# 10.39842    1
# 6.94813     1
# 6.35744     1
# 5.81959     1
# 11.25981    1
# 20.61847    1
# 6.13473     1
# 7.51110     1
# 19.86185    1
# 6.24328     1
# 9.92945     1
# 9.67397     1
# 22.02416    1
# 5.64362     1
# 12.61053    1
# 9.39507     1
# 6.81602     1
# 21.34112    1
# 6.66685     1
# 6.88054     1
# 14.46189    1
# 24.37521    1
# 5.88211     1
# 7.22363     1
# 16.71042    1
# 11.65129    1
# 7.70237     1
# Name: MDG_0000000001, dtype: int64
#
# PCV3
# 93.0    7
# 92.0    4
# 94.0    1
# Name: PCV3, dtype: int64
#
# ROTAC
# 73.0    4
# 72.0    2
# 74.0    1
# 69.0    1
# 67.0    1
# 59.0    1
# 44.0    1
# Name: ROTAC, dtype: int64
#
# WHS4_100
# 96.0    14
# 94.0     9
# 95.0     8
# 97.0     5
# 88.0     1
# 83.0     1
# 86.0     1
# 90.0     1
# Name: WHS4_100, dtype: int64
#
# WHS4_117
# 92.0    6
# 93.0    5
# 91.0    4
# 90.0    2
# 88.0    2
# 94.0    1
# 89.0    1
# 87.0    1
# 84.0    1
# 82.0    1
# 68.0    1
# 42.0    1
# 16.0    1
# Name: WHS4_117, dtype: int64
#
# WHS4_129
# 93.0    13
# 94.0     5
# 91.0     4
# 92.0     1
# 90.0     1
# 84.0     1
# Name: WHS4_129, dtype: int64
#
# WHS4_543
# Series([], Name: WHS4_543, dtype: int64)
#
# WHS4_544
# 93.0    10
# 97.0     6
# 91.0     5
# 94.0     4
# 90.0     3
# 92.0     2
# 96.0     2
# 89.0     1
# 88.0     1
# 84.0     1
# 79.0     1
# 72.0     1
# 78.0     1
# 85.0     1
# 95.0     1
# Name: WHS4_544, dtype: int64
#
# WHS8_110
# 92.0    14
# 91.0     6
# 97.0     4
# 90.0     3
# 98.0     3
# 93.0     2
# 88.0     1
# 89.0     1
# 84.0     1
# 83.0     1
# 87.0     1
# 94.0     1
# 82.0     1
# 86.0     1
# Name: WHS8_110, dtype: int64
#
# MCV2
# 86.0    7
# 94.0    3
# 91.0    2
# 95.0    1
# 93.0    1
# 92.0    1
# 90.0    1
# 89.0    1
# 88.0    1
# 87.0    1
# 85.0    1
# Name: MCV2, dtype: int64
#
# NUTRITION_564
# Series([], Name: NUTRITION_564, dtype: int64)
#
# WHS4_128
# Series([], Name: WHS4_128, dtype: int64)
#
# LBW_NUMBER
# 321.1    2
# 319.3    1
# 317.6    1
# 319.2    1
# 297.3    1
# 328.7    1
# 338.6    1
# 308.1    1
# 336.4    1
# 325.6    1
# 324.5    1
# 333.0    1
# 336.5    1
# 338.5    1
# 332.0    1
# Name: LBW_NUMBER, dtype: int64
#
# LBW_PREVALENCE
# 8.2    5
# 8.1    4
# 8.0    4
# 7.7    1
# 7.9    1
# 7.5    1
# Name: LBW_PREVALENCE, dtype: int64
#
# NUTRITION_HA_2
# Series([], Name: NUTRITION_HA_2, dtype: int64)
#
# NUTRITION_WA_2
# Series([], Name: NUTRITION_WA_2, dtype: int64)
#
# NUTRITION_WH2
# Series([], Name: NUTRITION_WH2, dtype: int64)
#
# NUTRITION_WH_2
# Series([], Name: NUTRITION_WH_2, dtype: int64)
#
# WHOSIS_000005
# Series([], Name: WHOSIS_000005, dtype: int64)
#
# WHOSIS_000006
# 25.51    1
# 26.43    1
# 23.26    1
# Name: WHOSIS_000006, dtype: int64
#
# MDG_0000000026
# 13.0    5
# 16.0    3
# 15.0    3
# 14.0    3
# 19.0    2
# 18.0    1
# 12.0    1
# Name: MDG_0000000026, dtype: int64
#
# WHS9_95
# 1.87    1
# Name: WHS9_95, dtype: int64
#
# WHS_PBR
# 12.0    1
# Name: WHS_PBR, dtype: int64
#
# WSH_2
# 18.1    1
# Name: WSH_2, dtype: int64
#
# WSH_3
# 0.92    1
# Name: WSH_3, dtype: int64
#
# WSH_SANITATION_SAFELY_MANAGED
# 89.44051    1
# 88.87550    1
# 89.90690    1
# 89.96700    1
# 88.76223    1
# 88.42129    1
# 89.32636    1
# 88.98858    1
# 88.64908    1
# 89.10147    1
# 89.84833    1
# 88.53513    1
# 89.55568    1
# 89.79068    1
# 88.19277    1
# 88.30727    1
# 89.67251    1
# 89.21416    1
# Name: WSH_SANITATION_SAFELY_MANAGED, dtype: int64
#
# M_Est_smk_curr
# 18.1    1
# 17.3    1
# 19.1    1
# 15.8    1
# 16.5    1
# 20.5    1
# Name: M_Est_smk_curr, dtype: int64
#
# M_Est_smk_daily
# 11.6    1
# 14.1    1
# 15.1    1
# 12.8    1
# 12.2    1
# 13.5    1
# Name: M_Est_smk_daily, dtype: int64
#
# TOBACCO_0000000192
# 16.3    1
# 17.3    1
# 19.9    1
# 15.0    1
# 23.0    1
# Name: TOBACCO_0000000192, dtype: int64
#
# GHED_CHEGDP_SHA2011
# 14.61    2
# 17.05    1
# 16.29    1
# 14.01    1
# 16.71    1
# 16.89    1
# 14.92    1
# 16.41    1
# 14.52    1
# 14.70    1
# 16.35    1
# 16.21    1
# 16.28    1
# 13.22    1
# 12.54    1
# 16.30    1
# 15.29    1
# 17.00    1
# Name: GHED_CHEGDP_SHA2011, dtype: int64
#
# WHS9_85
# Series([], Name: WHS9_85, dtype: int64)
#
# skipping col: Country Code
#
# skipping col: Year
#
# GDP
# 7.437000e+11    1
# 4.338979e+12    1
# 1.093642e+13    1
# 1.871496e+13    1
# 2.081826e+12    1
# 9.062818e+12    1
# 6.051000e+11    1
# 1.619701e+13    1
# 1.444893e+13    1
# 3.343789e+12    1
# 1.822470e+13    1
# 1.303664e+13    1
# 8.150000e+11    1
# 1.499205e+13    1
# 6.158129e+12    1
# 1.471284e+13    1
# 2.351599e+12    1
# 6.386000e+11    1
# 9.425000e+11    1
# 8.617000e+11    1
# 2.857307e+12    1
# 1.164850e+12    1
# 5.641580e+12    1
# 1.025235e+13    1
# 4.579631e+12    1
# 7.639749e+12    1
# 1.279110e+12    1
# 1.678485e+13    1
# 2.143323e+13    1
# 1.221373e+13    1
# 8.577554e+12    1
# 1.545243e+12    1
# 1.073303e+12    1
# 1.425376e+12    1
# 1.381461e+13    1
# 3.634038e+12    1
# 5.633000e+11    1
# 4.855215e+12    1
# 1.019900e+12    1
# 5.236438e+12    1
# 5.433000e+11    1
# 2.627334e+12    1
# 6.858559e+12    1
# 7.287236e+12    1
# 1.684904e+12    1
# 1.752716e+13    1
# 6.520327e+12    1
# 1.951935e+13    1
# 2.058016e+13    1
# 8.073122e+12    1
# 1.445186e+13    1
# 1.145824e+13    1
# 1.554258e+13    1
# 4.037613e+12    1
# 9.630664e+12    1
# 5.963144e+12    1
# 6.858000e+11    1
# 3.207042e+12    1
# 1.058182e+13    1
# 1.873412e+12    1
# Name: GDP, dtype: int64

# %%
cols_to_use
# Out:
# ['MDG_0000000001',
#  'PCV3',
#  'ROTAC',
#  'WHS4_100',
#  'WHS4_117',
#  'WHS4_129',
#  'WHS4_544',
#  'WHS8_110',
#  'MCV2',
#  'LBW_NUMBER',
#  'LBW_PREVALENCE',
#  'WHOSIS_000006',
#  'MDG_0000000026',
#  'WHS9_95',
#  'WHS_PBR',
#  'WSH_2',
#  'WSH_3',
#  'WSH_SANITATION_SAFELY_MANAGED',
#  'M_Est_smk_curr',
#  'M_Est_smk_daily',
#  'TOBACCO_0000000192',
#  'GHED_CHEGDP_SHA2011',
#  'GDP']

# %%
who_subset = who_usa[cols_to_use]

# %%
who_usa.head()
# Out:
#       Country_Year  MDG_0000000001  PCV3  ROTAC  WHS4_100  WHS4_117  WHS4_129  \
# 10619     USA_1960        25.88741   NaN    NaN       NaN       NaN       NaN
# 10620     USA_1961        25.39648   NaN    NaN       NaN       NaN       NaN
# 10621     USA_1962        24.89482   NaN    NaN       NaN       NaN       NaN
# 10622     USA_1963        24.37521   NaN    NaN       NaN       NaN       NaN
# 10623     USA_1964        23.82979   NaN    NaN       NaN       NaN       NaN
#
#        WHS4_543  WHS4_544  WHS8_110  ...  WSH_3  \
# 10619       NaN       NaN       NaN  ...    NaN
# 10620       NaN       NaN       NaN  ...    NaN
# 10621       NaN       NaN       NaN  ...    NaN
# 10622       NaN       NaN       NaN  ...    NaN
# 10623       NaN       NaN       NaN  ...    NaN
#
#        WSH_SANITATION_SAFELY_MANAGED  M_Est_smk_curr  M_Est_smk_daily  \
# 10619                            NaN             NaN              NaN
# 10620                            NaN             NaN              NaN
# 10621                            NaN             NaN              NaN
# 10622                            NaN             NaN              NaN
# 10623                            NaN             NaN              NaN
#
#        TOBACCO_0000000192  GHED_CHEGDP_SHA2011  WHS9_85  Country Code    Year  \
# 10619                 NaN                  NaN      NaN           USA  1960.0
# 10620                 NaN                  NaN      NaN           USA  1961.0
# 10621                 NaN                  NaN      NaN           USA  1962.0
# 10622                 NaN                  NaN      NaN           USA  1963.0
# 10623                 NaN                  NaN      NaN           USA  1964.0
#
#                 GDP
# 10619  5.433000e+11
# 10620  5.633000e+11
# 10621  6.051000e+11
# 10622  6.386000e+11
# 10623  6.858000e+11
#
# [5 rows x 35 columns]

# %%
for col in who_subset.columns:
    print(col)
    print(who_subset[col].value_counts(), '\n')
# Out:
# MDG_0000000001
# 7.92969     1
# 12.10270    1
# 8.48050     1
# 15.93040    1
# 19.08584    1
# 8.78733     1
# 15.17808    1
# 7.35440     1
# 6.74598     1
# 6.47105     1
# 22.66503    1
# 25.88741    1
# 7.11413     1
# 5.76500     1
# 25.39648    1
# 13.17504    1
# 18.29825    1
# 10.92870    1
# 5.55743     1
# 7.02394     1
# 6.57525     1
# 6.03823     1
# 5.95398     1
# 24.89482    1
# 8.19128     1
# 23.82979    1
# 10.64615    1
# 17.50237    1
# 13.79409    1
# 10.16498    1
# 9.09776     1
# 23.26247    1
# 5.71130     1
# 10.39842    1
# 6.94813     1
# 6.35744     1
# 5.81959     1
# 11.25981    1
# 20.61847    1
# 6.13473     1
# 7.51110     1
# 19.86185    1
# 6.24328     1
# 9.92945     1
# 9.67397     1
# 22.02416    1
# 5.64362     1
# 12.61053    1
# 9.39507     1
# 6.81602     1
# 21.34112    1
# 6.66685     1
# 6.88054     1
# 14.46189    1
# 24.37521    1
# 5.88211     1
# 7.22363     1
# 16.71042    1
# 11.65129    1
# 7.70237     1
# Name: MDG_0000000001, dtype: int64
#
# PCV3
# 93.0    7
# 92.0    4
# 94.0    1
# Name: PCV3, dtype: int64
#
# ROTAC
# 73.0    4
# 72.0    2
# 74.0    1
# 69.0    1
# 67.0    1
# 59.0    1
# 44.0    1
# Name: ROTAC, dtype: int64
#
# WHS4_100
# 96.0    14
# 94.0     9
# 95.0     8
# 97.0     5
# 88.0     1
# 83.0     1
# 86.0     1
# 90.0     1
# Name: WHS4_100, dtype: int64
#
# WHS4_117
# 92.0    6
# 93.0    5
# 91.0    4
# 90.0    2
# 88.0    2
# 94.0    1
# 89.0    1
# 87.0    1
# 84.0    1
# 82.0    1
# 68.0    1
# 42.0    1
# 16.0    1
# Name: WHS4_117, dtype: int64
#
# WHS4_129
# 93.0    13
# 94.0     5
# 91.0     4
# 92.0     1
# 90.0     1
# 84.0     1
# Name: WHS4_129, dtype: int64
#
# WHS4_544
# 93.0    10
# 97.0     6
# 91.0     5
# 94.0     4
# 90.0     3
# 92.0     2
# 96.0     2
# 89.0     1
# 88.0     1
# 84.0     1
# 79.0     1
# 72.0     1
# 78.0     1
# 85.0     1
# 95.0     1
# Name: WHS4_544, dtype: int64
#
# WHS8_110
# 92.0    14
# 91.0     6
# 97.0     4
# 90.0     3
# 98.0     3
# 93.0     2
# 88.0     1
# 89.0     1
# 84.0     1
# 83.0     1
# 87.0     1
# 94.0     1
# 82.0     1
# 86.0     1
# Name: WHS8_110, dtype: int64
#
# MCV2
# 86.0    7
# 94.0    3
# 91.0    2
# 95.0    1
# 93.0    1
# 92.0    1
# 90.0    1
# 89.0    1
# 88.0    1
# 87.0    1
# 85.0    1
# Name: MCV2, dtype: int64
#
# LBW_NUMBER
# 321.1    2
# 319.3    1
# 317.6    1
# 319.2    1
# 297.3    1
# 328.7    1
# 338.6    1
# 308.1    1
# 336.4    1
# 325.6    1
# 324.5    1
# 333.0    1
# 336.5    1
# 338.5    1
# 332.0    1
# Name: LBW_NUMBER, dtype: int64
#
# LBW_PREVALENCE
# 8.2    5
# 8.1    4
# 8.0    4
# 7.7    1
# 7.9    1
# 7.5    1
# Name: LBW_PREVALENCE, dtype: int64
#
# WHOSIS_000006
# 25.51    1
# 26.43    1
# 23.26    1
# Name: WHOSIS_000006, dtype: int64
#
# MDG_0000000026
# 13.0    5
# 16.0    3
# 15.0    3
# 14.0    3
# 19.0    2
# 18.0    1
# 12.0    1
# Name: MDG_0000000026, dtype: int64
#
# WHS9_95
# 1.87    1
# Name: WHS9_95, dtype: int64
#
# WHS_PBR
# 12.0    1
# Name: WHS_PBR, dtype: int64
#
# WSH_2
# 18.1    1
# Name: WSH_2, dtype: int64
#
# WSH_3
# 0.92    1
# Name: WSH_3, dtype: int64
#
# WSH_SANITATION_SAFELY_MANAGED
# 89.44051    1
# 88.87550    1
# 89.90690    1
# 89.96700    1
# 88.76223    1
# 88.42129    1
# 89.32636    1
# 88.98858    1
# 88.64908    1
# 89.10147    1
# 89.84833    1
# 88.53513    1
# 89.55568    1
# 89.79068    1
# 88.19277    1
# 88.30727    1
# 89.67251    1
# 89.21416    1
# Name: WSH_SANITATION_SAFELY_MANAGED, dtype: int64
#
# M_Est_smk_curr
# 18.1    1
# 17.3    1
# 19.1    1
# 15.8    1
# 16.5    1
# 20.5    1
# Name: M_Est_smk_curr, dtype: int64
#
# M_Est_smk_daily
# 11.6    1
# 14.1    1
# 15.1    1
# 12.8    1
# 12.2    1
# 13.5    1
# Name: M_Est_smk_daily, dtype: int64
#
# TOBACCO_0000000192
# 16.3    1
# 17.3    1
# 19.9    1
# 15.0    1
# 23.0    1
# Name: TOBACCO_0000000192, dtype: int64
#
# GHED_CHEGDP_SHA2011
# 14.61    2
# 17.05    1
# 16.29    1
# 14.01    1
# 16.71    1
# 16.89    1
# 14.92    1
# 16.41    1
# 14.52    1
# 14.70    1
# 16.35    1
# 16.21    1
# 16.28    1
# 13.22    1
# 12.54    1
# 16.30    1
# 15.29    1
# 17.00    1
# Name: GHED_CHEGDP_SHA2011, dtype: int64
#
# GDP
# 7.437000e+11    1
# 4.338979e+12    1
# 1.093642e+13    1
# 1.871496e+13    1
# 2.081826e+12    1
# 9.062818e+12    1
# 6.051000e+11    1
# 1.619701e+13    1
# 1.444893e+13    1
# 3.343789e+12    1
# 1.822470e+13    1
# 1.303664e+13    1
# 8.150000e+11    1
# 1.499205e+13    1
# 6.158129e+12    1
# 1.471284e+13    1
# 2.351599e+12    1
# 6.386000e+11    1
# 9.425000e+11    1
# 8.617000e+11    1
# 2.857307e+12    1
# 1.164850e+12    1
# 5.641580e+12    1
# 1.025235e+13    1
# 4.579631e+12    1
# 7.639749e+12    1
# 1.279110e+12    1
# 1.678485e+13    1
# 2.143323e+13    1
# 1.221373e+13    1
# 8.577554e+12    1
# 1.545243e+12    1
# 1.073303e+12    1
# 1.425376e+12    1
# 1.381461e+13    1
# 3.634038e+12    1
# 5.633000e+11    1
# 4.855215e+12    1
# 1.019900e+12    1
# 5.236438e+12    1
# 5.433000e+11    1
# 2.627334e+12    1
# 6.858559e+12    1
# 7.287236e+12    1
# 1.684904e+12    1
# 1.752716e+13    1
# 6.520327e+12    1
# 1.951935e+13    1
# 2.058016e+13    1
# 8.073122e+12    1
# 1.445186e+13    1
# 1.145824e+13    1
# 1.554258e+13    1
# 4.037613e+12    1
# 9.630664e+12    1
# 5.963144e+12    1
# 6.858000e+11    1
# 3.207042e+12    1
# 1.058182e+13    1
# 1.873412e+12    1
# Name: GDP, dtype: int64

# %%
#ALL "relevant cols"
cols_to_use = [
    'MDG_0000000001',
    'PCV3',
    'ROTAC',
    'WHS4_100',
    'WHS4_117',
    'WHS4_129',
    'WHS4_544',
    'WHS8_110',
    'MCV2',
    'LBW_NUMBER',
    'LBW_PREVALENCE',
    'MDG_0000000026',
    'WHS_PBR',
    'WSH_SANITATION_SAFELY_MANAGED',
    'M_Est_smk_curr',
    'M_Est_smk_daily',
    'TOBACCO_0000000192',
    'GHED_CHEGDP_SHA2011',
    'GDP'
]

#Relevant cols where you don't lose too much data between them
cols_for_pca = [
    'MDG_0000000001',
    'WHS4_100',
    'WHS4_117',
    'WHS4_129',
    'WHS4_544',
    'WHS8_110',
    'GDP'
]

# %%
who_subset = who_usa[cols_to_use]

# %%
who_subset
# Out:
#        MDG_0000000001  PCV3  ROTAC  WHS4_100  WHS4_117  WHS4_129  WHS4_544  \
# 10619        25.88741   NaN    NaN       NaN       NaN       NaN       NaN
# 10620        25.39648   NaN    NaN       NaN       NaN       NaN       NaN
# 10621        24.89482   NaN    NaN       NaN       NaN       NaN       NaN
# 10622        24.37521   NaN    NaN       NaN       NaN       NaN       NaN
# 10623        23.82979   NaN    NaN       NaN       NaN       NaN       NaN
# 10624        23.26247   NaN    NaN       NaN       NaN       NaN       NaN
# 10625        22.66503   NaN    NaN       NaN       NaN       NaN       NaN
# 10626        22.02416   NaN    NaN       NaN       NaN       NaN       NaN
# 10627        21.34112   NaN    NaN       NaN       NaN       NaN       NaN
# 10628        20.61847   NaN    NaN       NaN       NaN       NaN       NaN
# 10629        19.86185   NaN    NaN       NaN       NaN       NaN       NaN
# 10630        19.08584   NaN    NaN       NaN       NaN       NaN       NaN
# 10631        18.29825   NaN    NaN       NaN       NaN       NaN       NaN
# 10632        17.50237   NaN    NaN       NaN       NaN       NaN       NaN
# 10633        16.71042   NaN    NaN       NaN       NaN       NaN       NaN
# 10634        15.93040   NaN    NaN       NaN       NaN       NaN       NaN
# 10635        15.17808   NaN    NaN       NaN       NaN       NaN       NaN
# 10636        14.46189   NaN    NaN       NaN       NaN       NaN       NaN
# 10637        13.79409   NaN    NaN       NaN       NaN       NaN       NaN
# 10638        13.17504   NaN    NaN       NaN       NaN       NaN       NaN
# 10639        12.61053   NaN    NaN      96.0       NaN       NaN      95.0
# 10640        12.10270   NaN    NaN      96.0       NaN       NaN      96.0
# 10641        11.65129   NaN    NaN      96.0       NaN       NaN      97.0
# 10642        11.25981   NaN    NaN      97.0       NaN       NaN      97.0
# 10643        10.92870   NaN    NaN      97.0       NaN       NaN      97.0
# 10644        10.64615   NaN    NaN      96.0       NaN       NaN      96.0
# 10645        10.39842   NaN    NaN      97.0       NaN       NaN      97.0
# 10646        10.16498   NaN    NaN      97.0       NaN       NaN      97.0
# 10647         9.92945   NaN    NaN      97.0       NaN       NaN      97.0
# 10648         9.67397   NaN    NaN      94.0       NaN       NaN      91.0
# 10649         9.39507   NaN    NaN      90.0       NaN       NaN      85.0
# 10650         9.09776   NaN    NaN      86.0       NaN       NaN      78.0
# 10651         8.78733   NaN    NaN      83.0       NaN       NaN      72.0
# 10652         8.48050   NaN    NaN      88.0      16.0       NaN      79.0
# 10653         8.19128   NaN    NaN      94.0      42.0       NaN      84.0
# 10654         7.92969   NaN    NaN      95.0      68.0      91.0      88.0
# 10655         7.70237   NaN    NaN      95.0      82.0      91.0      91.0
# 10656         7.51110   NaN    NaN      96.0      84.0      93.0      91.0
# 10657         7.35440   NaN    NaN      96.0      87.0      93.0      91.0
# 10658         7.22363   NaN    NaN      96.0      88.0      94.0      90.0
# 10659         7.11413   NaN    NaN      94.0      90.0      93.0      90.0
# 10660         7.02394   NaN    NaN      94.0      89.0      93.0      89.0
# 10661         6.94813   NaN    NaN      94.0      88.0      93.0      90.0
# 10662         6.88054   NaN    NaN      96.0      92.0      94.0      91.0
# 10663         6.81602   NaN    NaN      96.0      92.0      94.0      92.0
# 10664         6.74598   NaN    NaN      96.0      93.0      94.0      92.0
# 10665         6.66685   NaN    NaN      96.0      93.0      93.0      93.0
# 10666         6.57525   NaN    NaN      96.0      93.0      93.0      93.0
# 10667         6.47105  93.0    NaN      96.0      94.0      91.0      94.0
# 10668         6.35744  93.0   44.0      95.0      92.0      84.0      93.0
# 10669         6.24328  93.0   59.0      95.0      92.0      90.0      93.0
# 10670         6.13473  94.0   67.0      96.0      91.0      94.0      94.0
# 10671         6.03823  92.0   69.0      94.0      90.0      93.0      93.0
# 10672         5.95398  92.0   73.0      94.0      91.0      93.0      93.0
# 10673         5.88211  93.0   72.0      95.0      92.0      93.0      93.0
# 10674         5.81959  93.0   72.0      95.0      92.0      93.0      93.0
# 10675         5.76500  93.0   73.0      95.0      93.0      93.0      94.0
# 10676         5.71130  93.0   73.0      95.0      93.0      93.0      94.0
# 10677         5.64362  92.0   73.0      94.0      91.0      92.0      93.0
# 10678         5.55743  92.0   74.0      94.0      91.0      91.0      93.0
#
#        WHS8_110  MCV2  LBW_NUMBER  LBW_PREVALENCE  MDG_0000000026  WHS_PBR  \
# 10619       NaN   NaN         NaN             NaN             NaN      NaN
# 10620       NaN   NaN         NaN             NaN             NaN      NaN
# 10621       NaN   NaN         NaN             NaN             NaN      NaN
# 10622       NaN   NaN         NaN             NaN             NaN      NaN
# 10623       NaN   NaN         NaN             NaN             NaN      NaN
# 10624       NaN   NaN         NaN             NaN             NaN      NaN
# 10625       NaN   NaN         NaN             NaN             NaN      NaN
# 10626       NaN   NaN         NaN             NaN             NaN      NaN
# 10627       NaN   NaN         NaN             NaN             NaN      NaN
# 10628       NaN   NaN         NaN             NaN             NaN      NaN
# 10629       NaN   NaN         NaN             NaN             NaN      NaN
# 10630       NaN   NaN         NaN             NaN             NaN      NaN
# 10631       NaN   NaN         NaN             NaN             NaN      NaN
# 10632       NaN   NaN         NaN             NaN             NaN      NaN
# 10633       NaN   NaN         NaN             NaN             NaN      NaN
# 10634       NaN   NaN         NaN             NaN             NaN      NaN
# 10635       NaN   NaN         NaN             NaN             NaN      NaN
# 10636       NaN   NaN         NaN             NaN             NaN      NaN
# 10637       NaN   NaN         NaN             NaN             NaN      NaN
# 10638       NaN   NaN         NaN             NaN             NaN      NaN
# 10639      86.0   NaN         NaN             NaN             NaN      NaN
# 10640      97.0   NaN         NaN             NaN             NaN      NaN
# 10641      97.0   NaN         NaN             NaN             NaN      NaN
# 10642      98.0   NaN         NaN             NaN             NaN      NaN
# 10643      98.0   NaN         NaN             NaN             NaN      NaN
# 10644      97.0   NaN         NaN             NaN             NaN      NaN
# 10645      97.0   NaN         NaN             NaN             NaN      NaN
# 10646      82.0   NaN         NaN             NaN             NaN      NaN
# 10647      98.0   NaN         NaN             NaN             NaN      NaN
# 10648      94.0   NaN         NaN             NaN             NaN      NaN
# 10649      90.0   NaN         NaN             NaN             NaN      NaN
# 10650      87.0   NaN         NaN             NaN             NaN      NaN
# 10651      83.0   NaN         NaN             NaN             NaN      NaN
# 10652      84.0   NaN         NaN             NaN             NaN      NaN
# 10653      89.0   NaN         NaN             NaN             NaN      NaN
# 10654      88.0   NaN         NaN             NaN             NaN      NaN
# 10655      91.0   NaN         NaN             NaN             NaN      NaN
# 10656      91.0   NaN         NaN             NaN             NaN      NaN
# 10657      92.0   NaN         NaN             NaN             NaN      NaN
# 10658      92.0   NaN         NaN             NaN             NaN      NaN
# 10659      91.0  85.0       297.3             7.5            12.0      NaN
# 10660      91.0  86.0       308.1             7.7            13.0      NaN
# 10661      91.0  86.0       317.6             7.9            13.0      NaN
# 10662      93.0  86.0       325.6             8.0            13.0      NaN
# 10663      93.0  86.0       332.0             8.1            13.0      NaN
# 10664      92.0  86.0       336.4             8.2            13.0      NaN
# 10665      92.0  86.0       338.6             8.2            14.0      NaN
# 10666      92.0  86.0       338.5             8.2            14.0      NaN
# 10667      92.0  87.0       336.5             8.2            14.0      NaN
# 10668      90.0  88.0       333.0             8.2            15.0      NaN
# 10669      92.0  89.0       328.7             8.1            15.0     12.0
# 10670      92.0  90.0       324.5             8.1            15.0      NaN
# 10671      91.0  91.0       321.1             8.1            16.0      NaN
# 10672      92.0  91.0       319.3             8.0            16.0      NaN
# 10673      92.0  92.0       319.2             8.0            16.0      NaN
# 10674      92.0  93.0       321.1             8.0            18.0      NaN
# 10675      92.0  94.0         NaN             NaN            19.0      NaN
# 10676      92.0  94.0         NaN             NaN            19.0      NaN
# 10677      92.0  94.0         NaN             NaN             NaN      NaN
# 10678      90.0  95.0         NaN             NaN             NaN      NaN
#
#        WSH_SANITATION_SAFELY_MANAGED  M_Est_smk_curr  M_Est_smk_daily  \
# 10619                            NaN             NaN              NaN
# 10620                            NaN             NaN              NaN
# 10621                            NaN             NaN              NaN
# 10622                            NaN             NaN              NaN
# 10623                            NaN             NaN              NaN
# 10624                            NaN             NaN              NaN
# 10625                            NaN             NaN              NaN
# 10626                            NaN             NaN              NaN
# 10627                            NaN             NaN              NaN
# 10628                            NaN             NaN              NaN
# 10629                            NaN             NaN              NaN
# 10630                            NaN             NaN              NaN
# 10631                            NaN             NaN              NaN
# 10632                            NaN             NaN              NaN
# 10633                            NaN             NaN              NaN
# 10634                            NaN             NaN              NaN
# 10635                            NaN             NaN              NaN
# 10636                            NaN             NaN              NaN
# 10637                            NaN             NaN              NaN
# 10638                            NaN             NaN              NaN
# 10639                            NaN             NaN              NaN
# 10640                            NaN             NaN              NaN
# 10641                            NaN             NaN              NaN
# 10642                            NaN             NaN              NaN
# 10643                            NaN             NaN              NaN
# 10644                            NaN             NaN              NaN
# 10645                            NaN             NaN              NaN
# 10646                            NaN             NaN              NaN
# 10647                            NaN             NaN              NaN
# 10648                            NaN             NaN              NaN
# 10649                            NaN             NaN              NaN
# 10650                            NaN             NaN              NaN
# 10651                            NaN             NaN              NaN
# 10652                            NaN             NaN              NaN
# 10653                            NaN             NaN              NaN
# 10654                            NaN             NaN              NaN
# 10655                            NaN             NaN              NaN
# 10656                            NaN             NaN              NaN
# 10657                            NaN             NaN              NaN
# 10658                            NaN             NaN              NaN
# 10659                       88.19277             NaN              NaN
# 10660                       88.30727             NaN              NaN
# 10661                       88.42129             NaN              NaN
# 10662                       88.53513             NaN              NaN
# 10663                       88.64908             NaN              NaN
# 10664                       88.76223             NaN              NaN
# 10665                       88.87550             NaN              NaN
# 10666                       88.98858            20.5             15.1
# 10667                       89.10147             NaN              NaN
# 10668                       89.21416             NaN              NaN
# 10669                       89.32636            19.1             14.1
# 10670                       89.44051             NaN              NaN
# 10671                       89.55568            18.1             13.5
# 10672                       89.67251             NaN              NaN
# 10673                       89.79068            17.3             12.8
# 10674                       89.84833             NaN              NaN
# 10675                       89.90690            16.5             12.2
# 10676                       89.96700             NaN              NaN
# 10677                            NaN            15.8             11.6
# 10678                            NaN             NaN              NaN
#
#        TOBACCO_0000000192  GHED_CHEGDP_SHA2011           GDP
# 10619                 NaN                  NaN  5.433000e+11
# 10620                 NaN                  NaN  5.633000e+11
# 10621                 NaN                  NaN  6.051000e+11
# 10622                 NaN                  NaN  6.386000e+11
# 10623                 NaN                  NaN  6.858000e+11
# 10624                 NaN                  NaN  7.437000e+11
# 10625                 NaN                  NaN  8.150000e+11
# 10626                 NaN                  NaN  8.617000e+11
# 10627                 NaN                  NaN  9.425000e+11
# 10628                 NaN                  NaN  1.019900e+12
# 10629                 NaN                  NaN  1.073303e+12
# 10630                 NaN                  NaN  1.164850e+12
# 10631                 NaN                  NaN  1.279110e+12
# 10632                 NaN                  NaN  1.425376e+12
# 10633                 NaN                  NaN  1.545243e+12
# 10634                 NaN                  NaN  1.684904e+12
# 10635                 NaN                  NaN  1.873412e+12
# 10636                 NaN                  NaN  2.081826e+12
# 10637                 NaN                  NaN  2.351599e+12
# 10638                 NaN                  NaN  2.627334e+12
# 10639                 NaN                  NaN  2.857307e+12
# 10640                 NaN                  NaN  3.207042e+12
# 10641                 NaN                  NaN  3.343789e+12
# 10642                 NaN                  NaN  3.634038e+12
# 10643                 NaN                  NaN  4.037613e+12
# 10644                 NaN                  NaN  4.338979e+12
# 10645                 NaN                  NaN  4.579631e+12
# 10646                 NaN                  NaN  4.855215e+12
# 10647                 NaN                  NaN  5.236438e+12
# 10648                 NaN                  NaN  5.641580e+12
# 10649                 NaN                  NaN  5.963144e+12
# 10650                 NaN                  NaN  6.158129e+12
# 10651                 NaN                  NaN  6.520327e+12
# 10652                 NaN                  NaN  6.858559e+12
# 10653                 NaN                  NaN  7.287236e+12
# 10654                 NaN                  NaN  7.639749e+12
# 10655                 NaN                  NaN  8.073122e+12
# 10656                 NaN                  NaN  8.577554e+12
# 10657                 NaN                  NaN  9.062818e+12
# 10658                 NaN                  NaN  9.630664e+12
# 10659                23.0                12.54  1.025235e+13
# 10660                 NaN                13.22  1.058182e+13
# 10661                 NaN                14.01  1.093642e+13
# 10662                 NaN                14.52  1.145824e+13
# 10663                 NaN                14.61  1.221373e+13
# 10664                19.9                14.61  1.303664e+13
# 10665                 NaN                14.70  1.381461e+13
# 10666                 NaN                14.92  1.445186e+13
# 10667                 NaN                15.29  1.471284e+13
# 10668                 NaN                16.28  1.444893e+13
# 10669                17.3                16.35  1.499205e+13
# 10670                 NaN                16.30  1.554258e+13
# 10671                16.3                16.29  1.619701e+13
# 10672                 NaN                16.21  1.678485e+13
# 10673                 NaN                16.41  1.752716e+13
# 10674                15.0                16.71  1.822470e+13
# 10675                 NaN                17.05  1.871496e+13
# 10676                 NaN                17.00  1.951935e+13
# 10677                 NaN                16.89  2.058016e+13
# 10678                 NaN                  NaN  2.143323e+13

# %%
who_subset = who_subset.dropna(how="any")

# %%
# Out:
#        MDG_0000000001  WHS4_100  WHS4_117  WHS4_129  WHS4_544  WHS8_110  \
# 10654         7.92969      95.0      68.0      91.0      88.0      88.0
# 10655         7.70237      95.0      82.0      91.0      91.0      91.0
# 10656         7.51110      96.0      84.0      93.0      91.0      91.0
# 10657         7.35440      96.0      87.0      93.0      91.0      92.0
# 10658         7.22363      96.0      88.0      94.0      90.0      92.0
# 10659         7.11413      94.0      90.0      93.0      90.0      91.0
# 10660         7.02394      94.0      89.0      93.0      89.0      91.0
# 10661         6.94813      94.0      88.0      93.0      90.0      91.0
# 10662         6.88054      96.0      92.0      94.0      91.0      93.0
# 10663         6.81602      96.0      92.0      94.0      92.0      93.0
# 10664         6.74598      96.0      93.0      94.0      92.0      92.0
# 10665         6.66685      96.0      93.0      93.0      93.0      92.0
# 10666         6.57525      96.0      93.0      93.0      93.0      92.0
# 10667         6.47105      96.0      94.0      91.0      94.0      92.0
# 10668         6.35744      95.0      92.0      84.0      93.0      90.0
# 10669         6.24328      95.0      92.0      90.0      93.0      92.0
# 10670         6.13473      96.0      91.0      94.0      94.0      92.0
# 10671         6.03823      94.0      90.0      93.0      93.0      91.0
# 10672         5.95398      94.0      91.0      93.0      93.0      92.0
# 10673         5.88211      95.0      92.0      93.0      93.0      92.0
# 10674         5.81959      95.0      92.0      93.0      93.0      92.0
# 10675         5.76500      95.0      93.0      93.0      94.0      92.0
# 10676         5.71130      95.0      93.0      93.0      94.0      92.0
# 10677         5.64362      94.0      91.0      92.0      93.0      92.0
# 10678         5.55743      94.0      91.0      91.0      93.0      90.0
#
#                 GDP
# 10654  7.639749e+12
# 10655  8.073122e+12
# 10656  8.577554e+12
# 10657  9.062818e+12
# 10658  9.630664e+12
# 10659  1.025235e+13
# 10660  1.058182e+13
# 10661  1.093642e+13
# 10662  1.145824e+13
# 10663  1.221373e+13
# 10664  1.303664e+13
# 10665  1.381461e+13
# 10666  1.445186e+13
# 10667  1.471284e+13
# 10668  1.444893e+13
# 10669  1.499205e+13
# 10670  1.554258e+13
# 10671  1.619701e+13
# 10672  1.678485e+13
# 10673  1.752716e+13
# 10674  1.822470e+13
# 10675  1.871496e+13
# 10676  1.951935e+13
# 10677  2.058016e+13
# 10678  2.143323e+13

# %%
from sklearn.preprocessing import StandardScaler
features = ['PCV3',
 'ROTAC',
 'WHS4_100',
 'WHS4_117',
 'WHS4_129',
 'WHS4_544',
 'WHS8_110',
 'MCV2',
 'LBW_NUMBER',
 'LBW_PREVALENCE',
 'MDG_0000000026',
 'WHS_PBR',
 'WSH_SANITATION_SAFELY_MANAGED',
 'M_Est_smk_curr',
 'M_Est_smk_daily',
 'TOBACCO_0000000192',
 'GHED_CHEGDP_SHA2011',
 'GDP']
# Separating out the features
x = who_subset.loc[:, features].values
# Separating out the target
y = who_subset.loc[:,['MDG_0000000001']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
who_subset
# Out:
#        PCV3  ROTAC  WHS4_100  WHS4_117  WHS4_129  WHS4_544  WHS8_110  MCV2  \
# 10619   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10620   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10621   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10622   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10623   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10624   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10625   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10626   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10627   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10628   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10629   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10630   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10631   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10632   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10633   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10634   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10635   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10636   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10637   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10638   NaN    NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 10639   NaN    NaN      96.0       NaN       NaN      95.0      86.0   NaN
# 10640   NaN    NaN      96.0       NaN       NaN      96.0      97.0   NaN
# 10641   NaN    NaN      96.0       NaN       NaN      97.0      97.0   NaN
# 10642   NaN    NaN      97.0       NaN       NaN      97.0      98.0   NaN
# 10643   NaN    NaN      97.0       NaN       NaN      97.0      98.0   NaN
# 10644   NaN    NaN      96.0       NaN       NaN      96.0      97.0   NaN
# 10645   NaN    NaN      97.0       NaN       NaN      97.0      97.0   NaN
# 10646   NaN    NaN      97.0       NaN       NaN      97.0      82.0   NaN
# 10647   NaN    NaN      97.0       NaN       NaN      97.0      98.0   NaN
# 10648   NaN    NaN      94.0       NaN       NaN      91.0      94.0   NaN
# 10649   NaN    NaN      90.0       NaN       NaN      85.0      90.0   NaN
# 10650   NaN    NaN      86.0       NaN       NaN      78.0      87.0   NaN
# 10651   NaN    NaN      83.0       NaN       NaN      72.0      83.0   NaN
# 10652   NaN    NaN      88.0      16.0       NaN      79.0      84.0   NaN
# 10653   NaN    NaN      94.0      42.0       NaN      84.0      89.0   NaN
# 10654   NaN    NaN      95.0      68.0      91.0      88.0      88.0   NaN
# 10655   NaN    NaN      95.0      82.0      91.0      91.0      91.0   NaN
# 10656   NaN    NaN      96.0      84.0      93.0      91.0      91.0   NaN
# 10657   NaN    NaN      96.0      87.0      93.0      91.0      92.0   NaN
# 10658   NaN    NaN      96.0      88.0      94.0      90.0      92.0   NaN
# 10659   NaN    NaN      94.0      90.0      93.0      90.0      91.0  85.0
# 10660   NaN    NaN      94.0      89.0      93.0      89.0      91.0  86.0
# 10661   NaN    NaN      94.0      88.0      93.0      90.0      91.0  86.0
# 10662   NaN    NaN      96.0      92.0      94.0      91.0      93.0  86.0
# 10663   NaN    NaN      96.0      92.0      94.0      92.0      93.0  86.0
# 10664   NaN    NaN      96.0      93.0      94.0      92.0      92.0  86.0
# 10665   NaN    NaN      96.0      93.0      93.0      93.0      92.0  86.0
# 10666   NaN    NaN      96.0      93.0      93.0      93.0      92.0  86.0
# 10667  93.0    NaN      96.0      94.0      91.0      94.0      92.0  87.0
# 10668  93.0   44.0      95.0      92.0      84.0      93.0      90.0  88.0
# 10669  93.0   59.0      95.0      92.0      90.0      93.0      92.0  89.0
# 10670  94.0   67.0      96.0      91.0      94.0      94.0      92.0  90.0
# 10671  92.0   69.0      94.0      90.0      93.0      93.0      91.0  91.0
# 10672  92.0   73.0      94.0      91.0      93.0      93.0      92.0  91.0
# 10673  93.0   72.0      95.0      92.0      93.0      93.0      92.0  92.0
# 10674  93.0   72.0      95.0      92.0      93.0      93.0      92.0  93.0
# 10675  93.0   73.0      95.0      93.0      93.0      94.0      92.0  94.0
# 10676  93.0   73.0      95.0      93.0      93.0      94.0      92.0  94.0
# 10677  92.0   73.0      94.0      91.0      92.0      93.0      92.0  94.0
# 10678  92.0   74.0      94.0      91.0      91.0      93.0      90.0  95.0
#
#        LBW_NUMBER  LBW_PREVALENCE  MDG_0000000026  WHS_PBR  \
# 10619         NaN             NaN             NaN      NaN
# 10620         NaN             NaN             NaN      NaN
# 10621         NaN             NaN             NaN      NaN
# 10622         NaN             NaN             NaN      NaN
# 10623         NaN             NaN             NaN      NaN
# 10624         NaN             NaN             NaN      NaN
# 10625         NaN             NaN             NaN      NaN
# 10626         NaN             NaN             NaN      NaN
# 10627         NaN             NaN             NaN      NaN
# 10628         NaN             NaN             NaN      NaN
# 10629         NaN             NaN             NaN      NaN
# 10630         NaN             NaN             NaN      NaN
# 10631         NaN             NaN             NaN      NaN
# 10632         NaN             NaN             NaN      NaN
# 10633         NaN             NaN             NaN      NaN
# 10634         NaN             NaN             NaN      NaN
# 10635         NaN             NaN             NaN      NaN
# 10636         NaN             NaN             NaN      NaN
# 10637         NaN             NaN             NaN      NaN
# 10638         NaN             NaN             NaN      NaN
# 10639         NaN             NaN             NaN      NaN
# 10640         NaN             NaN             NaN      NaN
# 10641         NaN             NaN             NaN      NaN
# 10642         NaN             NaN             NaN      NaN
# 10643         NaN             NaN             NaN      NaN
# 10644         NaN             NaN             NaN      NaN
# 10645         NaN             NaN             NaN      NaN
# 10646         NaN             NaN             NaN      NaN
# 10647         NaN             NaN             NaN      NaN
# 10648         NaN             NaN             NaN      NaN
# 10649         NaN             NaN             NaN      NaN
# 10650         NaN             NaN             NaN      NaN
# 10651         NaN             NaN             NaN      NaN
# 10652         NaN             NaN             NaN      NaN
# 10653         NaN             NaN             NaN      NaN
# 10654         NaN             NaN             NaN      NaN
# 10655         NaN             NaN             NaN      NaN
# 10656         NaN             NaN             NaN      NaN
# 10657         NaN             NaN             NaN      NaN
# 10658         NaN             NaN             NaN      NaN
# 10659       297.3             7.5            12.0      NaN
# 10660       308.1             7.7            13.0      NaN
# 10661       317.6             7.9            13.0      NaN
# 10662       325.6             8.0            13.0      NaN
# 10663       332.0             8.1            13.0      NaN
# 10664       336.4             8.2            13.0      NaN
# 10665       338.6             8.2            14.0      NaN
# 10666       338.5             8.2            14.0      NaN
# 10667       336.5             8.2            14.0      NaN
# 10668       333.0             8.2            15.0      NaN
# 10669       328.7             8.1            15.0     12.0
# 10670       324.5             8.1            15.0      NaN
# 10671       321.1             8.1            16.0      NaN
# 10672       319.3             8.0            16.0      NaN
# 10673       319.2             8.0            16.0      NaN
# 10674       321.1             8.0            18.0      NaN
# 10675         NaN             NaN            19.0      NaN
# 10676         NaN             NaN            19.0      NaN
# 10677         NaN             NaN             NaN      NaN
# 10678         NaN             NaN             NaN      NaN
#
#        WSH_SANITATION_SAFELY_MANAGED  M_Est_smk_curr  M_Est_smk_daily  \
# 10619                            NaN             NaN              NaN
# 10620                            NaN             NaN              NaN
# 10621                            NaN             NaN              NaN
# 10622                            NaN             NaN              NaN
# 10623                            NaN             NaN              NaN
# 10624                            NaN             NaN              NaN
# 10625                            NaN             NaN              NaN
# 10626                            NaN             NaN              NaN
# 10627                            NaN             NaN              NaN
# 10628                            NaN             NaN              NaN
# 10629                            NaN             NaN              NaN
# 10630                            NaN             NaN              NaN
# 10631                            NaN             NaN              NaN
# 10632                            NaN             NaN              NaN
# 10633                            NaN             NaN              NaN
# 10634                            NaN             NaN              NaN
# 10635                            NaN             NaN              NaN
# 10636                            NaN             NaN              NaN
# 10637                            NaN             NaN              NaN
# 10638                            NaN             NaN              NaN
# 10639                            NaN             NaN              NaN
# 10640                            NaN             NaN              NaN
# 10641                            NaN             NaN              NaN
# 10642                            NaN             NaN              NaN
# 10643                            NaN             NaN              NaN
# 10644                            NaN             NaN              NaN
# 10645                            NaN             NaN              NaN
# 10646                            NaN             NaN              NaN
# 10647                            NaN             NaN              NaN
# 10648                            NaN             NaN              NaN
# 10649                            NaN             NaN              NaN
# 10650                            NaN             NaN              NaN
# 10651                            NaN             NaN              NaN
# 10652                            NaN             NaN              NaN
# 10653                            NaN             NaN              NaN
# 10654                            NaN             NaN              NaN
# 10655                            NaN             NaN              NaN
# 10656                            NaN             NaN              NaN
# 10657                            NaN             NaN              NaN
# 10658                            NaN             NaN              NaN
# 10659                       88.19277             NaN              NaN
# 10660                       88.30727             NaN              NaN
# 10661                       88.42129             NaN              NaN
# 10662                       88.53513             NaN              NaN
# 10663                       88.64908             NaN              NaN
# 10664                       88.76223             NaN              NaN
# 10665                       88.87550             NaN              NaN
# 10666                       88.98858            20.5             15.1
# 10667                       89.10147             NaN              NaN
# 10668                       89.21416             NaN              NaN
# 10669                       89.32636            19.1             14.1
# 10670                       89.44051             NaN              NaN
# 10671                       89.55568            18.1             13.5
# 10672                       89.67251             NaN              NaN
# 10673                       89.79068            17.3             12.8
# 10674                       89.84833             NaN              NaN
# 10675                       89.90690            16.5             12.2
# 10676                       89.96700             NaN              NaN
# 10677                            NaN            15.8             11.6
# 10678                            NaN             NaN              NaN
#
#        TOBACCO_0000000192  GHED_CHEGDP_SHA2011           GDP
# 10619                 NaN                  NaN  5.433000e+11
# 10620                 NaN                  NaN  5.633000e+11
# 10621                 NaN                  NaN  6.051000e+11
# 10622                 NaN                  NaN  6.386000e+11
# 10623                 NaN                  NaN  6.858000e+11
# 10624                 NaN                  NaN  7.437000e+11
# 10625                 NaN                  NaN  8.150000e+11
# 10626                 NaN                  NaN  8.617000e+11
# 10627                 NaN                  NaN  9.425000e+11
# 10628                 NaN                  NaN  1.019900e+12
# 10629                 NaN                  NaN  1.073303e+12
# 10630                 NaN                  NaN  1.164850e+12
# 10631                 NaN                  NaN  1.279110e+12
# 10632                 NaN                  NaN  1.425376e+12
# 10633                 NaN                  NaN  1.545243e+12
# 10634                 NaN                  NaN  1.684904e+12
# 10635                 NaN                  NaN  1.873412e+12
# 10636                 NaN                  NaN  2.081826e+12
# 10637                 NaN                  NaN  2.351599e+12
# 10638                 NaN                  NaN  2.627334e+12
# 10639                 NaN                  NaN  2.857307e+12
# 10640                 NaN                  NaN  3.207042e+12
# 10641                 NaN                  NaN  3.343789e+12
# 10642                 NaN                  NaN  3.634038e+12
# 10643                 NaN                  NaN  4.037613e+12
# 10644                 NaN                  NaN  4.338979e+12
# 10645                 NaN                  NaN  4.579631e+12
# 10646                 NaN                  NaN  4.855215e+12
# 10647                 NaN                  NaN  5.236438e+12
# 10648                 NaN                  NaN  5.641580e+12
# 10649                 NaN                  NaN  5.963144e+12
# 10650                 NaN                  NaN  6.158129e+12
# 10651                 NaN                  NaN  6.520327e+12
# 10652                 NaN                  NaN  6.858559e+12
# 10653                 NaN                  NaN  7.287236e+12
# 10654                 NaN                  NaN  7.639749e+12
# 10655                 NaN                  NaN  8.073122e+12
# 10656                 NaN                  NaN  8.577554e+12
# 10657                 NaN                  NaN  9.062818e+12
# 10658                 NaN                  NaN  9.630664e+12
# 10659                23.0                12.54  1.025235e+13
# 10660                 NaN                13.22  1.058182e+13
# 10661                 NaN                14.01  1.093642e+13
# 10662                 NaN                14.52  1.145824e+13
# 10663                 NaN                14.61  1.221373e+13
# 10664                19.9                14.61  1.303664e+13
# 10665                 NaN                14.70  1.381461e+13
# 10666                 NaN                14.92  1.445186e+13
# 10667                 NaN                15.29  1.471284e+13
# 10668                 NaN                16.28  1.444893e+13
# 10669                17.3                16.35  1.499205e+13
# 10670                 NaN                16.30  1.554258e+13
# 10671                16.3                16.29  1.619701e+13
# 10672                 NaN                16.21  1.678485e+13
# 10673                 NaN                16.41  1.752716e+13
# 10674                15.0                16.71  1.822470e+13
# 10675                 NaN                17.05  1.871496e+13
# 10676                 NaN                17.00  1.951935e+13
# 10677                 NaN                16.89  2.058016e+13
# 10678                 NaN                  NaN  2.143323e+13

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-09ddbcf18128> in <module>()
#       1 from sklearn.decomposition import PCA
#       2 pca = PCA(n_components=2)
# ----> 3 principalComponents = pca.fit_transform(x)
#       4 principalDf = pd.DataFrame(data = principalComponents
#       5              , columns = ['principal component 1', 'principal component 2'])
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\sklearn\decomposition\pca.py in fit_transform(self, X, y)
#     358
#     359         """
# --> 360         U, S, V = self._fit(X)
#     361         U = U[:, :self.n_components_]
#     362
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     380
#     381         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 382                         copy=self.copy)
#     383
#     384         # Handle n_components==None
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
