# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model
import numpy as np
import statsmodels.api as sm

df = pd.read_csv("../data/WHO-SIMPLE.csv")

# %%
#Examine data frame and determine which year has the most complete data set
df.head()
df.describe()

df2 = df
#df2 = df2.set_index(['Year'])

#df2.groupby(['Year']).count()
#df2.groupby(['Year']).count().sum(axis=1)
df.groupby(['Year']).count().sum(axis=1)

df3 = df
df3 = df3.dropna(thresh=500, axis=1)
df3

df2['SUM'] = df3.count(axis=1)
df2 = df2[df2['SUM'] > 19]
df2.columns

df = df2

df2
# Out:
#       Country_Year  MDG_0000000001  PCV3  ROTAC  WHS4_100  WHS4_117  WHS4_129  \
# 51        AFG_2013        57.22515   NaN    NaN      64.0      64.0      64.0
# 56        AFG_2018        48.04333  65.0   45.0      66.0      66.0      66.0
# 85        AGO_2007        90.49068   NaN    NaN      48.0      43.0      43.0
# 93        AGO_2015        57.81665  55.0   40.0      59.0      55.0      55.0
# 120       ALB_2000        24.09920   NaN    NaN      97.0      96.0       NaN
# 125       ALB_2005        17.82718   NaN    NaN      98.0      98.0       NaN
# 127       ALB_2007        15.29248   NaN    NaN      98.0      98.0       NaN
# 130       ALB_2010        11.82810   NaN    NaN      99.0      99.0      99.0
# 131       ALB_2011        10.82506  99.0    NaN      99.0      99.0      99.0
# 132       ALB_2012         9.96302  99.0    NaN      99.0      99.0      99.0
# 133       ALB_2013         9.28442  99.0    NaN      99.0      99.0      99.0
# 134       ALB_2014         8.80597  99.0    NaN      98.0      98.0      98.0
# 135       ALB_2015         8.50946  99.0    NaN      99.0      99.0      99.0
# 136       ALB_2016         8.37872  98.0    NaN      98.0      98.0      98.0
# 222       ARE_2007         7.85969   NaN    NaN      92.0      92.0      92.0
# 225       ARE_2010         7.25447  94.0    NaN      94.0      94.0      94.0
# 227       ARE_2012         6.95578  96.0    NaN      96.0      96.0      96.0
# 229       ARE_2014         6.76584  99.0   56.0      99.0      99.0      99.0
# 230       ARE_2015         6.70241  99.0   87.0      99.0      99.0      99.0
# 231       ARE_2016         6.64436  99.0   92.0      99.0      99.0      99.0
# 276       ARG_2010        12.90835   NaN    NaN      94.0      94.0      94.0
# 278       ARG_2012        11.85737  41.0    NaN      91.0      91.0      91.0
# 280       ARG_2014        10.75480  89.0    NaN      94.0      94.0      94.0
# 281       ARG_2015        10.22042  82.0   61.0      94.0      94.0      94.0
# 315       ARM_2005        21.25712   NaN    NaN      90.0      91.0       NaN
# 320       ARM_2010        16.53714   NaN    NaN      94.0      94.0      48.0
# 322       ARM_2012        14.93910   NaN    NaN      95.0      95.0      95.0
# 324       ARM_2014        13.51420   NaN   91.0      93.0      93.0      93.0
# 325       ARM_2015        12.84986  44.0   93.0      94.0      94.0      94.0
# 326       ARM_2016        12.22385  94.0   94.0      94.0      94.0      94.0
# ...            ...             ...   ...    ...       ...       ...       ...
# 10975     VUT_2013        24.71131   NaN    NaN      84.0      83.0      86.0
# 11046     WSM_2014        14.86658   NaN    NaN      81.0      81.0      81.0
# 11093     YEM_2003        59.70229   NaN    NaN      61.0      38.0       NaN
# 11101     YEM_2011        43.07747  41.0    NaN      69.0      69.0      69.0
# 11102     YEM_2012        42.96415  67.0   23.0      67.0      67.0      67.0
# 11103     YEM_2013        42.96296  73.0   56.0      73.0      73.0      73.0
# 11104     YEM_2014        42.98612  73.0   57.0      73.0      73.0      73.0
# 11143     ZAF_2007        45.00486   NaN    NaN      85.0      83.0      84.0
# 11144     ZAF_2008        41.23283   NaN    NaN      82.0      76.0      80.0
# 11145     ZAF_2009        36.46015  10.0   17.0      81.0      74.0      77.0
# 11146     ZAF_2010        32.52628  58.0   60.0      77.0      71.0      72.0
# 11147     ZAF_2011        30.52789  62.0   67.0      75.0      76.0      71.0
# 11148     ZAF_2012        29.76645  75.0   74.0      71.0      70.0      69.0
# 11149     ZAF_2013        29.22565  77.0   77.0      81.0      73.0      79.0
# 11150     ZAF_2014        28.97082  85.0   85.0      85.0      85.0      85.0
# 11151     ZAF_2015        28.50314  85.0   85.0      85.0      85.0      85.0
# 11152     ZAF_2016        28.24151  77.0   73.0      76.0      76.0      76.0
# 11210     ZMB_2007        58.37457   NaN    NaN      80.0      80.0      80.0
# 11213     ZMB_2010        52.32319   NaN    NaN      83.0      83.0      83.0
# 11215     ZMB_2012        49.92345   NaN    NaN      78.0      78.0      78.0
# 11217     ZMB_2014        47.47225  77.0   73.0      86.0      86.0      86.0
# 11218     ZMB_2015        46.72124  81.0   82.0      90.0      90.0      90.0
# 11219     ZMB_2016        45.78916  90.0   90.0      91.0      91.0      91.0
# 11278     ZWE_2009        55.86600   NaN    NaN      73.0      73.0      73.0
# 11279     ZWE_2010        53.77652   NaN    NaN      89.0      90.0      90.0
# 11281     ZWE_2012        47.85339  21.0    NaN      95.0      97.0      97.0
# 11283     ZWE_2014        44.24571  91.0   48.0      91.0      91.0      91.0
# 11284     ZWE_2015        42.86801  87.0   87.0      87.0      87.0      87.0
# 11285     ZWE_2016        41.39206  90.0   91.0      90.0      90.0      90.0
# 11288     ZWE_2019        38.42378  90.0   92.0      90.0      90.0      90.0
#
#        WHS4_543  WHS4_544  WHS8_110 ...   WSH_SANITATION_SAFELY_MANAGED  \
# 51         72.0      64.0      57.0 ...                             NaN
# 56         78.0      73.0      64.0 ...                             NaN
# 85         75.0      43.0      58.0 ...                             NaN
# 93         64.0      57.0      51.0 ...                             NaN
# 120        93.0      97.0      95.0 ...                        38.61018
# 125        98.0      97.0      97.0 ...                        37.81890
# 127        98.0      99.0      97.0 ...                        37.62228
# 130        99.0      99.0      99.0 ...                        38.63999
# 131        97.0      99.0      99.0 ...                        38.97484
# 132        96.0      99.0      98.0 ...                        39.29807
# 133        99.0      99.0      99.0 ...                        39.59755
# 134        99.0      98.0      98.0 ...                        39.83249
# 135        99.0      99.0      97.0 ...                        39.84033
# 136        99.0      98.0      96.0 ...                        39.84799
# 222        98.0      94.0      92.0 ...                        92.11962
# 225        98.0      94.0      94.0 ...                        93.36774
# 227        94.0      96.0      96.0 ...                        94.19982
# 229        90.0      99.0      99.0 ...                        95.03191
# 230        96.0      99.0      99.0 ...                        95.44794
# 231        99.0      99.0      99.0 ...                        95.86398
# 276        99.0      95.0      95.0 ...                             NaN
# 278        99.0      90.0      94.0 ...                             NaN
# 280        99.0      92.0      95.0 ...                             NaN
# 281        96.0      93.0      89.0 ...                             NaN
# 315        94.0      92.0      94.0 ...                        47.90306
# 320        95.0      96.0      97.0 ...                        48.13523
# 322        96.0      96.0      97.0 ...                        48.21355
# 324        99.0      95.0      97.0 ...                        48.28449
# 325        99.0      96.0      97.0 ...                        48.31633
# 326        99.0      96.0      97.0 ...                        48.30069
# ...         ...       ...       ... ...                             ...
# 10975      93.0      78.0      84.0 ...                             NaN
# 11046      89.0      78.0      82.0 ...                        48.83835
# 11093      66.0      61.0      64.0 ...                             NaN
# 11101      59.0      69.0      66.0 ...                             NaN
# 11102      64.0      68.0      63.0 ...                             NaN
# 11103      71.0      67.0      70.0 ...                             NaN
# 11104      73.0      67.0      67.0 ...                             NaN
# 11143      79.0      79.0      68.0 ...                             NaN
# 11144      84.0      77.0      73.0 ...                             NaN
# 11145      82.0      75.0      77.0 ...                             NaN
# 11146      81.0      72.0      72.0 ...                             NaN
# 11147      84.0      71.0      77.0 ...                             NaN
# 11148      86.0      69.0      79.0 ...                             NaN
# 11149      88.0      79.0      78.0 ...                             NaN
# 11150      93.0      85.0      84.0 ...                             NaN
# 11151      83.0      85.0      86.0 ...                             NaN
# 11152      90.0      76.0      85.0 ...                             NaN
# 11210      91.0      77.0      93.0 ...                             NaN
# 11213      92.0      80.0      96.0 ...                             NaN
# 11215      92.0      70.0      82.0 ...                             NaN
# 11217      99.0      78.0      85.0 ...                             NaN
# 11218      97.0      90.0      90.0 ...                             NaN
# 11219      99.0      87.0      93.0 ...                             NaN
# 11278      90.0      69.0      76.0 ...                             NaN
# 11279      99.0      89.0      90.0 ...                             NaN
# 11281      98.0      95.0      97.0 ...                             NaN
# 11283      99.0      92.0      92.0 ...                             NaN
# 11284      90.0      88.0      86.0 ...                             NaN
# 11285      95.0      90.0      95.0 ...                             NaN
# 11288      95.0      90.0      85.0 ...                             NaN
#
#        M_Est_smk_curr  M_Est_smk_daily  TOBACCO_0000000192  \
# 51                NaN              NaN                 NaN
# 56                NaN              NaN                 NaN
# 85                NaN              NaN                 NaN
# 93                NaN              NaN                 NaN
# 120               NaN              NaN                11.6
# 125               NaN              NaN                10.1
# 127               9.7              7.6                 NaN
# 130               9.4              7.3                 8.7
# 131               NaN              NaN                 NaN
# 132               9.1              7.1                 8.2
# 133               NaN              NaN                 NaN
# 134               8.9              6.9                 NaN
# 135               NaN              NaN                 7.6
# 136               8.7              6.8                 NaN
# 222               0.9              0.6                 NaN
# 225               0.8              0.5                 NaN
# 227               0.7              0.5                 NaN
# 229               0.6              0.4                 NaN
# 230               NaN              NaN                 NaN
# 231               0.6              0.4                 NaN
# 276              21.4             15.2                22.4
# 278              19.5             13.8                20.8
# 280              17.5             12.5                 NaN
# 281               NaN              NaN                18.4
# 315               NaN              NaN                 2.2
# 320               2.0              1.7                 1.8
# 322               1.9              1.6                 1.7
# 324               1.8              1.5                 NaN
# 325               NaN              NaN                 1.5
# 326               1.7              1.5                 NaN
# ...               ...              ...                 ...
# 10975             NaN              NaN                 NaN
# 11046            17.9             13.2                 NaN
# 11093             NaN              NaN                 NaN
# 11101             NaN              NaN                 NaN
# 11102             8.1              5.4                 NaN
# 11103             NaN              NaN                 NaN
# 11104             7.2              4.8                 NaN
# 11143             9.3              7.6                 NaN
# 11144             NaN              NaN                 NaN
# 11145             NaN              NaN                 NaN
# 11146             8.6              7.0                 8.0
# 11147             NaN              NaN                 NaN
# 11148             8.1              6.7                 7.4
# 11149             NaN              NaN                 NaN
# 11150             7.7              6.3                 NaN
# 11151             NaN              NaN                 6.5
# 11152             7.3              6.0                 NaN
# 11210             3.0              2.1                 NaN
# 11213             2.7              1.8                 5.0
# 11215             2.5              1.7                 4.8
# 11217             2.3              1.6                 NaN
# 11218             NaN              NaN                 4.6
# 11219             2.1              1.4                 NaN
# 11278             NaN              NaN                 NaN
# 11279             1.5              1.2                 2.4
# 11281             1.4              1.1                 2.3
# 11283             1.3              1.0                 NaN
# 11284             NaN              NaN                 2.1
# 11285             1.2              0.9                 NaN
# 11288             NaN              NaN                 NaN
#
#        GHED_CHEGDP_SHA2011  WHS9_85  Country Code    Year           GDP  SUM
# 51                    8.81      NaN           AFG  2013.0  2.056107e+10   20
# 56                    9.40      NaN           AFG  2018.0  1.835388e+10   21
# 85                    2.97      NaN           AGO  2007.0  6.526645e+10   21
# 93                    2.61      NaN           AGO  2015.0  1.161936e+11   21
# 120                   7.23      NaN           ALB  2000.0  3.480355e+09   24
# 125                   6.34      NaN           ALB  2005.0  8.052076e+09   25
# 127                   6.32      NaN           ALB  2007.0  1.067732e+10   20
# 130                   4.75      NaN           ALB  2010.0  1.192693e+10   22
# 131                   4.80      NaN           ALB  2011.0  1.289077e+10   20
# 132                   5.06      NaN           ALB  2012.0  1.231983e+10   23
# 133                   5.39      NaN           ALB  2013.0  1.277622e+10   20
# 134                   5.50      NaN           ALB  2014.0  1.322814e+10   22
# 135                   4.90      NaN           ALB  2015.0  1.138685e+10   21
# 136                   4.92      NaN           ALB  2016.0  1.186120e+10   20
# 222                   2.57      NaN           ARE  2007.0  2.579161e+11   20
# 225                   3.88      NaN           ARE  2010.0  2.897873e+11   21
# 227                   3.43      NaN           ARE  2012.0  3.745906e+11   21
# 229                   3.63      NaN           ARE  2014.0  4.031371e+11   22
# 230                   3.58      NaN           ARE  2015.0  3.581351e+11   20
# 231                   3.40      NaN           ARE  2016.0  3.570451e+11   20
# 276                   9.45      NaN           ARG  2010.0  4.236274e+11   20
# 278                   9.83      NaN           ARG  2012.0  5.459824e+11   21
# 280                   9.67      NaN           ARG  2014.0  5.263197e+11   20
# 281                  10.23      NaN           ARG  2015.0  5.947493e+11   20
# 315                   5.86      NaN           ARM  2005.0  4.900470e+09   24
# 320                   9.24      NaN           ARM  2010.0  9.260285e+09   27
# 322                   9.13      NaN           ARM  2012.0  1.061932e+10   21
# 324                  10.18      NaN           ARM  2014.0  1.160951e+10   21
# 325                  10.12      NaN           ARM  2015.0  1.055334e+10   22
# 326                   9.95      NaN           ARM  2016.0  1.054614e+10   20
# ...                    ...      ...           ...     ...           ...  ...
# 10975                 4.15      NaN           VUT  2013.0  8.017876e+08   23
# 11046                 6.23      NaN           WSM  2014.0  7.569199e+08   23
# 11093                 5.76      NaN           YEM  2003.0  1.177797e+10   20
# 11101                 4.77      NaN           YEM  2011.0  3.272642e+10   22
# 11102                 5.20      NaN           YEM  2012.0  3.540134e+10   20
# 11103                 4.96      NaN           YEM  2013.0  4.041524e+10   24
# 11104                 4.84      NaN           YEM  2014.0  4.320647e+10   20
# 11143                 6.43      NaN           ZAF  2007.0  2.994155e+11   20
# 11144                 6.55      NaN           ZAF  2008.0  2.867698e+11   23
# 11145                 7.11      NaN           ZAF  2009.0  2.959365e+11   20
# 11146                 7.42      NaN           ZAF  2010.0  3.753494e+11   23
# 11147                 7.50      NaN           ZAF  2011.0  4.164189e+11   20
# 11148                 7.75      NaN           ZAF  2012.0  3.963327e+11   27
# 11149                 7.72      NaN           ZAF  2013.0  3.668294e+11   20
# 11150                 7.93      NaN           ZAF  2014.0  3.509046e+11   22
# 11151                 8.20      NaN           ZAF  2015.0  3.176205e+11   21
# 11152                 8.10      NaN           ZAF  2016.0  2.963573e+11   25
# 11210                 4.35      NaN           ZMB  2007.0  1.405696e+10   25
# 11213                 3.72      NaN           ZMB  2010.0  2.026556e+10   20
# 11215                 3.93      NaN           ZMB  2012.0  2.550306e+10   20
# 11217                 3.83      NaN           ZMB  2014.0  2.715073e+10   22
# 11218                 4.44      NaN           ZMB  2015.0  2.124334e+10   21
# 11219                 4.48      NaN           ZMB  2016.0  2.095475e+10   20
# 11278                  NaN      NaN           ZWE  2009.0  9.665793e+09   22
# 11279                10.48      NaN           ZWE  2010.0  1.204166e+10   21
# 11281                 6.92      NaN           ZWE  2012.0  1.711485e+10   21
# 11283                 8.13      NaN           ZWE  2014.0  1.949552e+10   27
# 11284                 7.45      NaN           ZWE  2015.0  1.996312e+10   25
# 11285                 7.65      NaN           ZWE  2016.0  2.054868e+10   20
# 11288                  NaN      NaN           ZWE  2019.0  2.144076e+10   20
#
# [910 rows x 36 columns]

# %%
#This is in progress: Z test, t-test and combine M_Est_smk_curr and tabaco
df2_describe = df2.describe()

M_Est_smk_curr_mean = df2_describe['M_Est_smk_curr']

df2_describe
# Out:
#        MDG_0000000001        PCV3       ROTAC    WHS4_100    WHS4_117  \
# count      910.000000  392.000000  295.000000  910.000000  835.000000
# mean        28.059590   79.892857   74.322034   89.017582   87.713772
# std         24.137548   22.559470   23.956622   12.081485   14.335923
# min          1.937070    1.000000    1.000000   23.000000    4.000000
# 25%          9.198215   74.750000   62.000000   85.000000   84.000000
# 50%         19.061715   89.000000   85.000000   93.000000   93.000000
# 75%         41.140188   95.000000   91.000000   97.000000   97.000000
# max        139.487620   99.000000   99.000000   99.000000   99.000000
#
#          WHS4_129    WHS4_543    WHS4_544    WHS8_110        MCV2     ...      \
# count  755.000000  820.000000  910.000000  910.000000  629.000000     ...
# mean    87.731126   92.179268   89.001099   88.465934   82.158983     ...
# std     15.049451   11.035997   11.587283   12.145725   19.732208     ...
# min      1.000000   23.000000   30.000000   34.000000    3.000000     ...
# 25%     85.000000   90.000000   85.000000   84.000000   75.000000     ...
# 50%     93.000000   96.000000   93.000000   93.000000   90.000000     ...
# 75%     97.000000   99.000000   97.000000   97.000000   96.000000     ...
# max     99.000000   99.000000   99.000000   99.000000   99.000000     ...
#
#             WSH_3  WSH_SANITATION_SAFELY_MANAGED  M_Est_smk_curr  \
# count   15.000000                     467.000000      466.000000
# mean    20.944000                      56.734185        9.615880
# std     32.050086                      30.281627        9.984132
# min      0.140000                       3.162620        0.000000
# 25%      4.450000                      27.064605        1.900000
# 50%      7.150000                      54.231170        5.250000
# 75%     17.450000                      88.490375       16.750000
# max    104.900000                     100.000000       56.300000
#
#        M_Est_smk_daily  TOBACCO_0000000192  GHED_CHEGDP_SHA2011  WHS9_85  \
# count       466.000000          339.000000           902.000000      0.0
# mean          7.156438           11.391445             6.090565      NaN
# std           7.628758            9.900760             2.639544      NaN
# min           0.000000            0.200000             1.600000      NaN
# 25%           1.400000            3.100000             4.192500      NaN
# 50%           3.600000            8.200000             5.700000      NaN
# 75%          12.800000           19.450000             7.657500      NaN
# max          45.100000           40.200000            24.260000      NaN
#
#               Year           GDP         SUM
# count   910.000000  9.070000e+02  910.000000
# mean   2010.449451  3.379313e+11   21.770330
# std       4.574668  1.331487e+12    1.906217
# min    2000.000000  2.703037e+07   20.000000
# 25%    2007.000000  1.116405e+10   20.000000
# 50%    2012.000000  3.965053e+10   21.000000
# 75%    2014.000000  1.910399e+11   23.000000
# max    2019.000000  1.822470e+13   30.000000
#
# [8 rows x 34 columns]

# %%
#Check columns left out
#df2.groupby(['Year']).count().filter(['WHS9_85'])

# %%
#Attempted filtering to 2016 and examined counts for different variables
df_2016 = df[df['Year'] == 2016]
df_2016.count()
# Out:
# Country_Year                     55
# MDG_0000000001                   55
# PCV3                             48
# ROTAC                            43
# WHS4_100                         55
# WHS4_117                         55
# WHS4_129                         55
# WHS4_543                         54
# WHS4_544                         55
# WHS8_110                         55
# MCV2                             48
# NUTRITION_564                     0
# WHS4_128                         47
# LBW_NUMBER                        0
# LBW_PREVALENCE                    0
# NUTRITION_HA_2                   18
# NUTRITION_WA_2                   17
# NUTRITION_WH2                    18
# NUTRITION_WH_2                   18
# WHOSIS_000006                    13
# MDG_0000000026                   55
# WSH_SANITATION_SAFELY_MANAGED    27
# M_Est_smk_curr                   52
# M_Est_smk_daily                  52
# TOBACCO_0000000192                0
# GHED_CHEGDP_SHA2011              55
# Country Code                     55
# Year                             55
# GDP                              55
# SUM                              55
# dtype: int64

# %%
#Examined 2014 and determined it has a more complete set of counts
df_2014 = df[df['Year'] == 2014]
df_2014.count()
# Out:
# Country_Year                     118
# MDG_0000000001                   118
# PCV3                              80
# ROTAC                             57
# WHS4_100                         118
# WHS4_117                         116
# WHS4_129                         118
# WHS4_543                         102
# WHS4_544                         118
# WHS8_110                         118
# MCV2                              97
# NUTRITION_564                     25
# WHS4_128                          68
# LBW_NUMBER                       106
# LBW_PREVALENCE                   106
# NUTRITION_HA_2                    34
# NUTRITION_WA_2                    33
# NUTRITION_WH2                     32
# NUTRITION_WH_2                    33
# WHOSIS_000006                     30
# MDG_0000000026                   118
# WSH_SANITATION_SAFELY_MANAGED     67
# M_Est_smk_curr                   110
# M_Est_smk_daily                  110
# TOBACCO_0000000192                 0
# GHED_CHEGDP_SHA2011              117
# Country Code                     118
# Year                             118
# GDP                              118
# SUM                              118
# dtype: int64

# %%
#Examined 2010 and determined it has a more complete set of counts
df_2010 = df[df['Year'] == 2010]
df_2010.count()
# Out:
# Country_Year                     124
# MDG_0000000001                   124
# PCV3                              39
# ROTAC                             20
# WHS4_100                         124
# WHS4_117                         115
# WHS4_129                         112
# WHS4_543                         100
# WHS4_544                         124
# WHS8_110                         124
# MCV2                              85
# NUTRITION_564                     21
# WHS4_128                          66
# LBW_NUMBER                       118
# LBW_PREVALENCE                   118
# NUTRITION_HA_2                    23
# NUTRITION_WA_2                    23
# NUTRITION_WH2                     23
# NUTRITION_WH_2                    23
# WHOSIS_000006                     31
# MDG_0000000026                   124
# WSH_SANITATION_SAFELY_MANAGED     72
# M_Est_smk_curr                   114
# M_Est_smk_daily                  114
# TOBACCO_0000000192               105
# GHED_CHEGDP_SHA2011              124
# Country Code                     124
# Year                             124
# GDP                              124
# SUM                              124
# dtype: int64

# %%
#Examined 2012 and determined it has a more complete set of counts
df_2012 = df[df['Year'] == 2012]
df_2012.count()
# Out:
# Country_Year                     136
# MDG_0000000001                   136
# PCV3                              68
# ROTAC                             32
# WHS4_100                         136
# WHS4_117                         127
# WHS4_129                         129
# WHS4_543                         110
# WHS4_544                         136
# WHS8_110                         136
# MCV2                             100
# NUTRITION_564                     22
# WHS4_128                          71
# LBW_NUMBER                       123
# LBW_PREVALENCE                   123
# NUTRITION_HA_2                    30
# NUTRITION_WA_2                    30
# NUTRITION_WH2                     29
# NUTRITION_WH_2                    30
# WHOSIS_000006                     29
# MDG_0000000026                   136
# WSH_SANITATION_SAFELY_MANAGED     77
# M_Est_smk_curr                   123
# M_Est_smk_daily                  123
# TOBACCO_0000000192               112
# GHED_CHEGDP_SHA2011              135
# Country Code                     136
# Year                             136
# GDP                              135
# SUM                              136
# dtype: int64

# %%
#Data without filter by year
counts = df.count()

counts
# Out:
# Country_Year                     910
# MDG_0000000001                   910
# PCV3                             392
# ROTAC                            295
# WHS4_100                         910
# WHS4_117                         835
# WHS4_129                         755
# WHS4_543                         820
# WHS4_544                         910
# WHS8_110                         910
# MCV2                             629
# NUTRITION_564                    318
# WHS4_128                         614
# LBW_NUMBER                       744
# LBW_PREVALENCE                   744
# NUTRITION_HA_2                   421
# NUTRITION_WA_2                   418
# NUTRITION_WH2                    406
# NUTRITION_WH_2                   420
# WHOSIS_000005                     12
# WHOSIS_000006                    289
# MDG_0000000026                   884
# WHS9_95                           55
# WHS_PBR                          123
# WSH_2                             15
# WSH_3                             15
# WSH_SANITATION_SAFELY_MANAGED    467
# M_Est_smk_curr                   466
# M_Est_smk_daily                  466
# TOBACCO_0000000192               339
# GHED_CHEGDP_SHA2011              902
# WHS9_85                            0
# Country Code                     910
# Year                             910
# GDP                              907
# SUM                              910
# dtype: int64

# %%
def scatterplot_2vars(df, x, y):
    plt.scatter(df[x], df[y], color='green')
    plt.title('{} Vs {}'.format(x,y), fontsize=14)
    plt.xlabel(x, fontsize=14)
    plt.ylabel(y, fontsize=14)
    plt.grid(True)
    plt.show()

def histogram(df, x):
    plt.hist(df[x], bins="auto", range=(0,df[x].max()))
    plt.title('{}'.format(x), fontsize=14)
    plt.xlabel(x, fontsize=14)
    plt.grid(True)
    plt.show()

# %%
#This is to examine if the relationships are linear. Not all are, but many are good! A few may need a 
# transformation (ie GDP) and a few may not work ultimately
columns_of_interest = ['PCV3',#'ROTAC','NUTRITION_564',
                       'WHS4_100','WHS4_117','WHS4_129','WHS4_543','WHS4_544','WHS8_110',
                       'MCV2','WHS4_128','LBW_NUMBER','LBW_PREVALENCE',
                       #'NUTRITION_HA_2','NUTRITION_WA_2',#'NUTRITION_WH2','NUTRITION_WH_2','WHOSIS_000006',
                       'MDG_0000000026','WSH_SANITATION_SAFELY_MANAGED',
                       #'WHS9_95','WHS_PBR','WSH_2','WSH_3',
                       #'M_Est_smk_curr','M_Est_smk_daily','TOBACCO_0000000192',
                       'GHED_CHEGDP_SHA2011','GDP']

df_transformed = df.copy()
df_transformed['GDP'] = np.log(df['GDP'])
df_transformed['LBW_NUMBER'] = np.log(df['LBW_NUMBER'])

for col in columns_of_interest:
    scatterplot_2vars(df_transformed, col, 'MDG_0000000001')
    histogram(df_transformed, col)

histogram(df_transformed, 'MDG_0000000001')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PCV3'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-e2b8fe82805c> in <module>()
#      15
#      16 for col in columns_of_interest:
# ---> 17     scatterplot_2vars(df_transformed, col, 'MDG_0000000001')
#      18     histogram(df_transformed, col)
#      19
#
# <ipython-input-54-3eba4e377880> in scatterplot_2vars(df, x, y)
#       1 def scatterplot_2vars(df, x, y):
# ----> 2     plt.scatter(df[x], df[y], color='green')
#       3     plt.title('{} Vs {}'.format(x,y), fontsize=14)
#       4     plt.xlabel(x, fontsize=14)
#       5     plt.ylabel(y, fontsize=14)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PCV3'

# %%
x_and_y_cols = columns_of_interest.copy()
x_and_y_cols.append('MDG_0000000001')
df_no_nan = df_transformed[x_and_y_cols].copy().dropna()
X = df_no_nan[columns_of_interest] # Our multiple variables
Y = df_no_nan['MDG_0000000001']

# %%
len(X)
# Out:
# 66

# %%
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  9.001983130683147
# Coefficients:
#  [-0.01077173  0.82582811 -0.58754481 -0.27792522  0.17801415  0.24459802
#  -0.28625995  0.05176226 -0.01563795  1.27306776  0.42134447  0.05680726
#  -0.00147089  0.54539594 -0.80365722]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         MDG_0000000001   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.971
# Method:                 Least Squares   F-statistic:                     146.8
# Date:                Thu, 25 Mar 2021   Prob (F-statistic):           6.38e-36
# Time:                        15:46:41   Log-Likelihood:                -131.34
# No. Observations:                  66   AIC:                             294.7
# Df Residuals:                      50   BIC:                             329.7
# Df Model:                          15
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             9.0020     20.141      0.447      0.657     -31.452      49.456
# PCV3                             -0.0108      0.015     -0.717      0.476      -0.041       0.019
# WHS4_100                          0.8258      0.912      0.905      0.370      -1.006       2.658
# WHS4_117                         -0.5875      0.283     -2.073      0.043      -1.157      -0.018
# WHS4_129                         -0.2779      1.026     -0.271      0.788      -2.339       1.783
# WHS4_543                          0.1780      0.124      1.432      0.158      -0.072       0.428
# WHS4_544                          0.2446      0.094      2.614      0.012       0.057       0.433
# WHS8_110                         -0.2863      0.080     -3.564      0.001      -0.448      -0.125
# MCV2                              0.0518      0.022      2.373      0.022       0.008       0.096
# WHS4_128                         -0.0156      0.065     -0.242      0.810      -0.146       0.114
# LBW_NUMBER                        1.2731      0.911      1.397      0.168      -0.557       3.103
# LBW_PREVALENCE                    0.4213      0.178      2.364      0.022       0.063       0.779
# MDG_0000000026                    0.0568      0.003     16.603      0.000       0.050       0.064
# WSH_SANITATION_SAFELY_MANAGED    -0.0015      0.029     -0.051      0.960      -0.060       0.057
# GHED_CHEGDP_SHA2011               0.5454      0.168      3.244      0.002       0.208       0.883
# GDP                              -0.8037      0.822     -0.978      0.333      -2.454       0.847
# ==============================================================================
# Omnibus:                        0.192   Durbin-Watson:                   1.206
# Prob(Omnibus):                  0.908   Jarque-Bera (JB):                0.070
# Skew:                          -0.079   Prob(JB):                        0.966
# Kurtosis:                       2.976   Cond. No.                     2.40e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model.conf_int()
# Out:
#                                        0          1
# const                         -31.452052  49.456018
# PCV3                           -0.040932   0.019389
# WHS4_100                       -1.006364   2.658020
# WHS4_117                       -1.156736  -0.018354
# WHS4_129                       -2.338917   1.783066
# WHS4_543                       -0.071755   0.427783
# WHS4_544                        0.056652   0.432544
# WHS8_110                       -0.447578  -0.124942
# MCV2                            0.007955   0.095570
# WHS4_128                       -0.145585   0.114309
# LBW_NUMBER                     -0.556676   3.102811
# LBW_PREVALENCE                  0.063339   0.779350
# MDG_0000000026                  0.049935   0.063679
# WSH_SANITATION_SAFELY_MANAGED  -0.059782   0.056840
# GHED_CHEGDP_SHA2011             0.207657   0.883135
# GDP                            -2.454124   0.846809
